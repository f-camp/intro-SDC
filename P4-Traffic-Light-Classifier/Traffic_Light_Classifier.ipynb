# %% [markdown]
# # Traffic Light Classifier
# ---
#
# In this project, you’ll use your knowledge of computer vision techniques to build a classifier for images of traffic lights! You'll be given a dataset of traffic light images in which one of three lights is illuminated: red, yellow, or green.
#
# In this notebook, you'll pre-process these images, extract features that will help us distinguish the different types of images, and use those features to classify the traffic light images into three classes: red, yellow, or green. The tasks will be broken down into a few sections:
#
# 1. **Loading and visualizing the data**.
#       The first step in any classification task is to be familiar with your data; you'll need to load in the images of traffic lights and visualize them!
#
# 2. **Pre-processing**.
#     The input images and output labels need to be standardized. This way, you can analyze all the input images using the same classification pipeline, and you know what output to expect when you eventually classify a *new* image.
#
# 3. **Feature extraction**.
#     Next, you'll extract some features from each image that will help distinguish and eventually classify these images.
#
# 4. **Classification and visualizing error**.
#     Finally, you'll write one function that uses your features to classify *any* traffic light image. This function will take in an image and output a label. You'll also be given code to determine the accuracy of your classification model.
#
# 5. **Evaluate your model**.
#     To pass this project, your classifier must be >90% accurate and never classify any red lights as green; it's likely that you'll need to improve the accuracy of your classifier by changing existing features or adding new features. I'd also encourage you to try to get as close to 100% accuracy as possible!
#
# Here are some sample images from the dataset (from left to right: red, green, and yellow traffic lights):
# <img src="images/all_lights.png" width="50%" height="50%">

# %%
# !tar -zcvf myfiles.tar.gz /
# Out:
# tar: Removing leading `/' from member names
# /
# /etc/
# /etc/fstab
# /etc/bindresvport.blacklist
# /etc/environment
# /etc/cron.weekly/
# /etc/cron.weekly/fstrim
# /etc/cron.weekly/.placeholder
# /etc/cron.weekly/man-db
# /etc/localtime
# /etc/sysctl.d/
# /etc/sysctl.d/10-link-restrictions.conf
# /etc/sysctl.d/10-kernel-hardening.conf
# /etc/sysctl.d/10-console-messages.conf
# /etc/sysctl.d/10-zeropage.conf
# /etc/sysctl.d/README
# /etc/sysctl.d/10-ptrace.conf
# /etc/sysctl.d/10-ipv6-privacy.conf
# /etc/sysctl.d/10-magic-sysrq.conf
# /etc/sysctl.d/99-sysctl.conf
# /etc/sysctl.d/10-network-security.conf
# /etc/sysctl.d/30-postgresql-shm.conf
# /etc/sysctl.d/cassandra.conf
# /etc/dpkg/
# /etc/dpkg/dpkg.cfg.d/
# /etc/dpkg/dpkg.cfg.d/pkg-config-hook-config
# /etc/dpkg/dpkg.cfg.d/docker-apt-speedup
# /etc/dpkg/origins/
# /etc/dpkg/origins/ubuntu
# /etc/dpkg/origins/debian
# /etc/dpkg/origins/default
# /etc/dpkg/dpkg.cfg
# /etc/dpkg/shlibs.override
# /etc/dpkg/shlibs.default
# /etc/dbus-1/
# /etc/dbus-1/system.d/
# /etc/dbus-1/system.d/org.freedesktop.resolve1.conf
# /etc/dbus-1/system.d/org.freedesktop.systemd1.conf
# /etc/dbus-1/system.d/org.freedesktop.locale1.conf
# /etc/dbus-1/system.d/org.freedesktop.timedate1.conf
# /etc/dbus-1/system.d/org.freedesktop.login1.conf
# /etc/dbus-1/system.d/org.freedesktop.network1.conf
# /etc/dbus-1/system.d/org.freedesktop.hostname1.conf
# /etc/dbus-1/system.d/com.ubuntu.SoftwareProperties.conf
# /etc/dbus-1/session.d/
# /etc/skel/
# /etc/skel/.bashrc
# /etc/skel/.profile
# /etc/skel/.bash_logout
# /etc/init/
# /etc/init/passwd.conf
# /etc/init/procps.conf
# /etc/init/hwclock-save.conf
# /etc/init/hostname.conf
# /etc/init/hostname.sh.conf
# /etc/init/hwclock.sh.conf
# /etc/init/hwclock.conf
# /etc/init/procps-instance.conf
# /etc/init/cron.conf
# /etc/init/networking.conf
# /etc/init/network-interface.conf
# /etc/init/network-interface-security.conf
# /etc/init/network-interface-container.conf
# /etc/init/dbus.conf
# /etc/networks
# /etc/legal
# /etc/kernel/
# /etc/kernel/postinst.d/
# /etc/kernel/postinst.d/apt-auto-removal
# /etc/rc6.d/
# /etc/rc6.d/K01urandom
# /etc/rc6.d/README
# /etc/rc6.d/K01postgresql
# /etc/rc6.d/K07reboot
# /etc/rc6.d/K02hwclock.sh
# /etc/rc6.d/K01cassandra
# /etc/rc6.d/K03umountnfs.sh
# /etc/rc6.d/K05umountfs
# /etc/rc6.d/K06umountroot
# /etc/rc6.d/K02sendsigs
# /etc/rc6.d/K04networking
# /etc/group
# /etc/nsswitch.conf
# /etc/insserv/
# /etc/insserv/overrides/
# /etc/systemd/
# /etc/systemd/resolved.conf
# /etc/systemd/bootchart.conf
# /etc/systemd/network/
# /etc/systemd/journald.conf
# /etc/systemd/user/
# /etc/systemd/logind.conf
# /etc/systemd/system/
# /etc/systemd/system/sysinit.target.wants/
# /etc/systemd/system/sysinit.target.wants/systemd-timesyncd.service
# /etc/systemd/system/getty.target.wants/
# /etc/systemd/system/getty.target.wants/getty@tty1.service
# /etc/systemd/system/multi-user.target.wants/
# /etc/systemd/system/multi-user.target.wants/remote-fs.target
# /etc/systemd/system/multi-user.target.wants/postgresql.service
# /etc/systemd/system/multi-user.target.wants/cron.service
# /etc/systemd/system/multi-user.target.wants/networking.service
# /etc/systemd/system/timers.target.wants/
# /etc/systemd/system/timers.target.wants/motd-news.timer
# /etc/systemd/system/timers.target.wants/apt-daily-upgrade.timer
# /etc/systemd/system/timers.target.wants/apt-daily.timer
# /etc/systemd/system/network-online.target.wants/
# /etc/systemd/system/network-online.target.wants/networking.service
# /etc/systemd/timesyncd.conf
# /etc/systemd/system.conf
# /etc/systemd/user.conf
# /etc/debian_version
# /etc/rc3.d/
# /etc/rc3.d/README
# /etc/rc3.d/S01cron
# /etc/rc3.d/S01postgresql
# /etc/rc3.d/S01sysstat
# /etc/rc3.d/S03rc.local
# /etc/rc3.d/S03ondemand
# /etc/rc3.d/S01ntp
# /etc/rc3.d/S02cassandra
# /etc/rc3.d/S01dbus
# /etc/security/
# /etc/security/namespace.conf
# /etc/security/limits.conf
# /etc/security/access.conf
# /etc/security/pam_env.conf
# /etc/security/sepermit.conf
# /etc/security/namespace.d/
# /etc/security/namespace.init
# /etc/security/opasswd
# /etc/security/time.conf
# /etc/security/limits.d/
# /etc/security/limits.d/cassandra.conf
# /etc/security/group.conf
# /etc/udev/
# /etc/profile.d/
# /etc/inputrc
# /etc/gshadow
# /etc/logrotate.d/
# /etc/logrotate.d/dpkg
# /etc/logrotate.d/apt
# /etc/logrotate.d/postgresql-common
# /etc/adduser.conf
# /etc/X11/
# /etc/X11/xinit/
# /etc/X11/xinit/xinitrc.d/
# /etc/X11/Xsession.d/
# /etc/X11/Xsession.d/99x11-common_start
# /etc/X11/Xsession.d/20x11-common_process-args
# /etc/X11/Xsession.d/40x11-common_xsessionrc
# /etc/X11/Xsession.d/35x11-common_xhost-local
# /etc/X11/Xsession.d/30x11-common_xresources
# /etc/X11/Xsession.d/50x11-common_determine-startup
# /etc/X11/Xsession.d/90x11-common_ssh-agent
# /etc/X11/Xsession.d/60x11-common_xdg_path
# /etc/X11/Xsession.d/60x11-common_localhost
# /etc/X11/Xsession.d/70gconfd_path-on-session
# /etc/X11/Xsession.d/95dbus_update-activation-env
# /etc/X11/Xsession.d/75dbus_dbus-launch
# /etc/X11/fonts/
# /etc/X11/fonts/Type1/
# /etc/X11/fonts/Type1/lmodern.scale
# /etc/X11/rgb.txt
# /etc/X11/Xsession.options
# /etc/X11/Xreset.d/
# /etc/X11/Xreset.d/README
# /etc/X11/Xsession
# /etc/X11/xkb/
# /etc/X11/Xresources/
# /etc/X11/Xresources/x11-common
# /etc/X11/Xreset
# /etc/dhcp/
# /etc/dhcp/dhclient-exit-hooks.d/
# /etc/dhcp/dhclient-exit-hooks.d/timesyncd
# /etc/dhcp/dhclient-exit-hooks.d/debug
# /etc/dhcp/dhclient-exit-hooks.d/rfc3442-classless-routes
# /etc/dhcp/dhclient-exit-hooks.d/ntp
# /etc/dhcp/dhclient.conf
# /etc/dhcp/dhclient-enter-hooks.d/
# /etc/dhcp/dhclient-enter-hooks.d/debug
# /etc/dhcp/debug
# /etc/rmt
# /etc/modules-load.d/
# /etc/modules-load.d/modules.conf
# /etc/hosts
# /etc/login.defs
# /etc/terminfo/
# /etc/terminfo/README
# /etc/profile
# /etc/subgid
# /etc/os-release
# /etc/alternatives/
# /etc/alternatives/w.1.gz
# /etc/alternatives/rmt.8.gz
# /etc/alternatives/nawk
# /etc/alternatives/w
# /etc/alternatives/rmt
# /etc/alternatives/pager
# /etc/alternatives/nawk.1.gz
# /etc/alternatives/builtins.7.gz
# /etc/alternatives/README
# /etc/alternatives/awk
# /etc/alternatives/awk.1.gz
# /etc/alternatives/pager.1.gz
# /etc/alternatives/DROP_LANGUAGE.7.gz
# /etc/alternatives/postgres.1.gz
# /etc/alternatives/ALTER_DOMAIN.7.gz
# /etc/alternatives/DROP_OPERATOR_FAMILY.7.gz
# /etc/alternatives/ANALYZE.7.gz
# /etc/alternatives/CREATE_EVENT_TRIGGER.7.gz
# /etc/alternatives/pgbench.1.gz
# /etc/alternatives/pg_basebackup.1.gz
# /etc/alternatives/CREATE_INDEX.7.gz
# /etc/alternatives/CREATE_AGGREGATE.7.gz
# /etc/alternatives/DROP_INDEX.7.gz
# /etc/alternatives/SET_SESSION_AUTHORIZATION.7.gz
# /etc/alternatives/DISCARD.7.gz
# /etc/alternatives/BEGIN.7.gz
# /etc/alternatives/sar
# /etc/alternatives/REVOKE.7.gz
# /etc/alternatives/DROP_TEXT_SEARCH_TEMPLATE.7.gz
# /etc/alternatives/DROP_AGGREGATE.7.gz
# /etc/alternatives/initdb.1.gz
# /etc/alternatives/ALTER_TYPE.7.gz
# /etc/alternatives/postmaster.1.gz
# /etc/alternatives/ALTER_LARGE_OBJECT.7.gz
# /etc/alternatives/START_TRANSACTION.7.gz
# /etc/alternatives/pg_test_timing.1.gz
# /etc/alternatives/TABLE.7.gz
# /etc/alternatives/DO.7.gz
# /etc/alternatives/SET.7.gz
# /etc/alternatives/ALTER_COLLATION.7.gz
# /etc/alternatives/DROP_GROUP.7.gz
# /etc/alternatives/DROP_COLLATION.7.gz
# /etc/alternatives/DROP_DATABASE.7.gz
# /etc/alternatives/DROP_ROLE.7.gz
# /etc/alternatives/INSERT.7.gz
# /etc/alternatives/DECLARE.7.gz
# /etc/alternatives/CREATE_MATERIALIZED_VIEW.7.gz
# /etc/alternatives/createlang.1.gz
# /etc/alternatives/RELEASE_SAVEPOINT.7.gz
# /etc/alternatives/ALTER_LANGUAGE.7.gz
# /etc/alternatives/ALTER_DATABASE.7.gz
# /etc/alternatives/CREATE_TABLE.7.gz
# /etc/alternatives/CREATE_USER.7.gz
# /etc/alternatives/DROP_FOREIGN_TABLE.7.gz
# /etc/alternatives/TRUNCATE.7.gz
# /etc/alternatives/ALTER_OPERATOR_FAMILY.7.gz
# /etc/alternatives/PREPARE_TRANSACTION.7.gz
# /etc/alternatives/CREATE_SCHEMA.7.gz
# /etc/alternatives/psql.1.gz
# /etc/alternatives/dropdb.1.gz
# /etc/alternatives/FETCH.7.gz
# /etc/alternatives/DROP_DOMAIN.7.gz
# /etc/alternatives/reindexdb.1.gz
# /etc/alternatives/CREATE_LANGUAGE.7.gz
# /etc/alternatives/LOCK.7.gz
# /etc/alternatives/ROLLBACK.7.gz
# /etc/alternatives/ALTER_FOREIGN_DATA_WRAPPER.7.gz
# /etc/alternatives/CHECKPOINT.7.gz
# /etc/alternatives/DROP_FOREIGN_DATA_WRAPPER.7.gz
# /etc/alternatives/createuser.1.gz
# /etc/alternatives/CREATE_DATABASE.7.gz
# /etc/alternatives/SET_TRANSACTION.7.gz
# /etc/alternatives/DROP_USER_MAPPING.7.gz
# /etc/alternatives/DROP_MATERIALIZED_VIEW.7.gz
# /etc/alternatives/ALTER_AGGREGATE.7.gz
# /etc/alternatives/CREATE_TABLESPACE.7.gz
# /etc/alternatives/CREATE_TABLE_AS.7.gz
# /etc/alternatives/CREATE_GROUP.7.gz
# /etc/alternatives/ALTER_SEQUENCE.7.gz
# /etc/alternatives/CREATE_FUNCTION.7.gz
# /etc/alternatives/ALTER_EXTENSION.7.gz
# /etc/alternatives/CREATE_SEQUENCE.7.gz
# /etc/alternatives/DROP_USER.7.gz
# /etc/alternatives/ALTER_USER_MAPPING.7.gz
# /etc/alternatives/pg_dump.1.gz
# /etc/alternatives/LOAD.7.gz
# /etc/alternatives/CREATE_TEXT_SEARCH_PARSER.7.gz
# /etc/alternatives/RESET.7.gz
# /etc/alternatives/DROP_TRANSFORM.7.gz
# /etc/alternatives/DROP_VIEW.7.gz
# /etc/alternatives/DROP_SERVER.7.gz
# /etc/alternatives/DELETE.7.gz
# /etc/alternatives/CREATE_USER_MAPPING.7.gz
# /etc/alternatives/CREATE_DOMAIN.7.gz
# /etc/alternatives/ALTER_SERVER.7.gz
# /etc/alternatives/CREATE_CONVERSION.7.gz
# /etc/alternatives/DROP_CONVERSION.7.gz
# /etc/alternatives/ALTER_TABLESPACE.7.gz
# /etc/alternatives/DROP_TABLE.7.gz
# /etc/alternatives/ALTER_SYSTEM.7.gz
# /etc/alternatives/clusterdb.1.gz
# /etc/alternatives/DROP_SEQUENCE.7.gz
# /etc/alternatives/pg_dumpall.1.gz
# /etc/alternatives/CREATE_SERVER.7.gz
# /etc/alternatives/ABORT.7.gz
# /etc/alternatives/CREATE_TEXT_SEARCH_TEMPLATE.7.gz
# /etc/alternatives/DROP_TEXT_SEARCH_CONFIGURATION.7.gz
# /etc/alternatives/DROP_OPERATOR_CLASS.7.gz
# /etc/alternatives/SET_CONSTRAINTS.7.gz
# /etc/alternatives/EXECUTE.7.gz
# /etc/alternatives/ALTER_TEXT_SEARCH_CONFIGURATION.7.gz
# /etc/alternatives/ALTER_TABLE.7.gz
# /etc/alternatives/ALTER_CONVERSION.7.gz
# /etc/alternatives/CREATE_POLICY.7.gz
# /etc/alternatives/droplang.1.gz
# /etc/alternatives/CREATE_VIEW.7.gz
# /etc/alternatives/ALTER_OPERATOR_CLASS.7.gz
# /etc/alternatives/DROP_OPERATOR.7.gz
# /etc/alternatives/createdb.1.gz
# /etc/alternatives/ALTER_SCHEMA.7.gz
# /etc/alternatives/ALTER_TEXT_SEARCH_DICTIONARY.7.gz
# /etc/alternatives/SELECT_INTO.7.gz
# /etc/alternatives/REASSIGN_OWNED.7.gz
# /etc/alternatives/ALTER_FUNCTION.7.gz
# /etc/alternatives/ROLLBACK_PREPARED.7.gz
# /etc/alternatives/EXPLAIN.7.gz
# /etc/alternatives/CREATE_FOREIGN_TABLE.7.gz
# /etc/alternatives/pg_recvlogical.1.gz
# /etc/alternatives/CREATE_CAST.7.gz
# /etc/alternatives/pg_resetxlog.1.gz
# /etc/alternatives/DROP_TABLESPACE.7.gz
# /etc/alternatives/MOVE.7.gz
# /etc/alternatives/CREATE_COLLATION.7.gz
# /etc/alternatives/UNLISTEN.7.gz
# /etc/alternatives/ALTER_ROLE.7.gz
# /etc/alternatives/SECURITY_LABEL.7.gz
# /etc/alternatives/DROP_EXTENSION.7.gz
# /etc/alternatives/pg_archivecleanup.1.gz
# /etc/alternatives/DROP_TEXT_SEARCH_DICTIONARY.7.gz
# /etc/alternatives/pg_upgrade.1.gz
# /etc/alternatives/ALTER_OPERATOR.7.gz
# /etc/alternatives/COMMENT.7.gz
# /etc/alternatives/DEALLOCATE.7.gz
# /etc/alternatives/DROP_CAST.7.gz
# /etc/alternatives/DROP_POLICY.7.gz
# /etc/alternatives/CREATE_OPERATOR_FAMILY.7.gz
# /etc/alternatives/SELECT.7.gz
# /etc/alternatives/ALTER_GROUP.7.gz
# /etc/alternatives/DROP_TYPE.7.gz
# /etc/alternatives/COMMIT.7.gz
# /etc/alternatives/pg_test_fsync.1.gz
# /etc/alternatives/CREATE_RULE.7.gz
# /etc/alternatives/GRANT.7.gz
# /etc/alternatives/CREATE_TEXT_SEARCH_DICTIONARY.7.gz
# /etc/alternatives/COPY.7.gz
# /etc/alternatives/ALTER_RULE.7.gz
# /etc/alternatives/oid2name.1.gz
# /etc/alternatives/CREATE_OPERATOR.7.gz
# /etc/alternatives/ALTER_TEXT_SEARCH_PARSER.7.gz
# /etc/alternatives/CREATE_TEXT_SEARCH_CONFIGURATION.7.gz
# /etc/alternatives/VACUUM.7.gz
# /etc/alternatives/pg_standby.1.gz
# /etc/alternatives/CREATE_OPERATOR_CLASS.7.gz
# /etc/alternatives/pg_receivexlog.1.gz
# /etc/alternatives/IMPORT_FOREIGN_SCHEMA.7.gz
# /etc/alternatives/pg_isready.1.gz
# /etc/alternatives/ALTER_FOREIGN_TABLE.7.gz
# /etc/alternatives/CLUSTER.7.gz
# /etc/alternatives/DROP_TRIGGER.7.gz
# /etc/alternatives/CREATE_ROLE.7.gz
# /etc/alternatives/ROLLBACK_TO_SAVEPOINT.7.gz
# /etc/alternatives/NOTIFY.7.gz
# /etc/alternatives/DROP_TEXT_SEARCH_PARSER.7.gz
# /etc/alternatives/CREATE_TRIGGER.7.gz
# /etc/alternatives/ALTER_MATERIALIZED_VIEW.7.gz
# /etc/alternatives/ALTER_VIEW.7.gz
# /etc/alternatives/DROP_FUNCTION.7.gz
# /etc/alternatives/vacuumdb.1.gz
# /etc/alternatives/CREATE_TYPE.7.gz
# /etc/alternatives/pg_controldata.1.gz
# /etc/alternatives/PREPARE.7.gz
# /etc/alternatives/ALTER_INDEX.7.gz
# /etc/alternatives/ALTER_DEFAULT_PRIVILEGES.7.gz
# /etc/alternatives/REINDEX.7.gz
# /etc/alternatives/END.7.gz
# /etc/alternatives/COMMIT_PREPARED.7.gz
# /etc/alternatives/CLOSE.7.gz
# /etc/alternatives/DROP_SCHEMA.7.gz
# /etc/alternatives/VALUES.7.gz
# /etc/alternatives/SHOW.7.gz
# /etc/alternatives/CREATE_FOREIGN_DATA_WRAPPER.7.gz
# /etc/alternatives/ALTER_TRIGGER.7.gz
# /etc/alternatives/CREATE_EXTENSION.7.gz
# /etc/alternatives/dropuser.1.gz
# /etc/alternatives/ALTER_USER.7.gz
# /etc/alternatives/CREATE_TRANSFORM.7.gz
# /etc/alternatives/pg_ctl.1.gz
# /etc/alternatives/SET_ROLE.7.gz
# /etc/alternatives/WITH.7.gz
# /etc/alternatives/UPDATE.7.gz
# /etc/alternatives/pg_rewind.1.gz
# /etc/alternatives/sar.1.gz
# /etc/alternatives/ALTER_EVENT_TRIGGER.7.gz
# /etc/alternatives/pg_xlogdump.1.gz
# /etc/alternatives/ALTER_TEXT_SEARCH_TEMPLATE.7.gz
# /etc/alternatives/REFRESH_MATERIALIZED_VIEW.7.gz
# /etc/alternatives/LISTEN.7.gz
# /etc/alternatives/DROP_EVENT_TRIGGER.7.gz
# /etc/alternatives/pg_restore.1.gz
# /etc/alternatives/SAVEPOINT.7.gz
# /etc/alternatives/ALTER_POLICY.7.gz
# /etc/alternatives/vacuumlo.1.gz
# /etc/alternatives/DROP_RULE.7.gz
# /etc/alternatives/DROP_OWNED.7.gz
# /etc/alternatives/unpack200.1.gz
# /etc/alternatives/java.1.gz
# /etc/alternatives/servertool
# /etc/alternatives/tnameserv.1.gz
# /etc/alternatives/keytool.1.gz
# /etc/alternatives/jjs.1.gz
# /etc/alternatives/pack200
# /etc/alternatives/rmid.1.gz
# /etc/alternatives/keytool
# /etc/alternatives/servertool.1.gz
# /etc/alternatives/jjs
# /etc/alternatives/orbd
# /etc/alternatives/jexec-binfmt
# /etc/alternatives/java
# /etc/alternatives/policytool.1.gz
# /etc/alternatives/policytool
# /etc/alternatives/rmid
# /etc/alternatives/rmiregistry.1.gz
# /etc/alternatives/unpack200
# /etc/alternatives/rmiregistry
# /etc/alternatives/jexec
# /etc/alternatives/tnameserv
# /etc/alternatives/orbd.1.gz
# /etc/alternatives/pack200.1.gz
# /etc/alternatives/nodejs
# /etc/alternatives/nodejs.1.gz
# /etc/alternatives/g++
# /etc/alternatives/gcc
# /etc/alternatives/ex.it.1.gz
# /etc/alternatives/vi.ja.1.gz
# /etc/alternatives/mpi-c.pc
# /etc/alternatives/c++.1.gz
# /etc/alternatives/vi.it.1.gz
# /etc/alternatives/view.it.1.gz
# /etc/alternatives/c89.1.gz
# /etc/alternatives/bibtex
# /etc/alternatives/lzcmp
# /etc/alternatives/c99.1.gz
# /etc/alternatives/lzmore.1.gz
# /etc/alternatives/emacs-document.svg
# /etc/alternatives/mpi-cxx.pc
# /etc/alternatives/rview
# /etc/alternatives/lzless.1.gz
# /etc/alternatives/view.pl.1.gz
# /etc/alternatives/cc
# /etc/alternatives/f77
# /etc/alternatives/f95
# /etc/alternatives/ebrowse
# /etc/alternatives/rename
# /etc/alternatives/rename.1.gz
# /etc/alternatives/ebrowse.1.gz
# /etc/alternatives/ex.ja.1.gz
# /etc/alternatives/lzegrep.1.gz
# /etc/alternatives/lzcat
# /etc/alternatives/unlzma.1.gz
# /etc/alternatives/mpiCC
# /etc/alternatives/unlzma
# /etc/alternatives/mpirun.1.gz
# /etc/alternatives/view.ru.1.gz
# /etc/alternatives/x-cursor-theme
# /etc/alternatives/emacs.svg
# /etc/alternatives/editor
# /etc/alternatives/jed-script
# /etc/alternatives/mpirun
# /etc/alternatives/libblas.so.3
# /etc/alternatives/mpi.pc
# /etc/alternatives/lzmore
# /etc/alternatives/f77.1.gz
# /etc/alternatives/c99
# /etc/alternatives/lzdiff
# /etc/alternatives/ex
# /etc/alternatives/view.fr.1.gz
# /etc/alternatives/c++
# /etc/alternatives/emacs-32x32.png
# /etc/alternatives/mpif77
# /etc/alternatives/lzma.1.gz
# /etc/alternatives/bibtex.1.gz
# /etc/alternatives/vim
# /etc/alternatives/mpic++
# /etc/alternatives/mpif77.1.gz
# /etc/alternatives/vi.fr.1.gz
# /etc/alternatives/mpiexec.1.gz
# /etc/alternatives/f95.1.gz
# /etc/alternatives/libmpi.so
# /etc/alternatives/cpp
# /etc/alternatives/emacs-128x128.png
# /etc/alternatives/ctags
# /etc/alternatives/emacs-16x16.png
# /etc/alternatives/lzma
# /etc/alternatives/cc.1.gz
# /etc/alternatives/liblapack.so.3
# /etc/alternatives/libmpi++.so
# /etc/alternatives/mpicc
# /etc/alternatives/ex.1.gz
# /etc/alternatives/mt
# /etc/alternatives/lzdiff.1.gz
# /etc/alternatives/lzfgrep.1.gz
# /etc/alternatives/emacs-24x24.png
# /etc/alternatives/mpicxx
# /etc/alternatives/ctags.1.gz
# /etc/alternatives/view
# /etc/alternatives/ex.ru.1.gz
# /etc/alternatives/view.ja.1.gz
# /etc/alternatives/vi
# /etc/alternatives/emacs
# /etc/alternatives/etags
# /etc/alternatives/c89
# /etc/alternatives/mt.1.gz
# /etc/alternatives/vimdiff
# /etc/alternatives/emacsclient
# /etc/alternatives/mpif90
# /etc/alternatives/ghostscript-current
# /etc/alternatives/lzgrep
# /etc/alternatives/mpiCC.1.gz
# /etc/alternatives/x86_64-linux-gnu_egl_conf
# /etc/alternatives/lzgrep.1.gz
# /etc/alternatives/vi.1.gz
# /etc/alternatives/mpif90.1.gz
# /etc/alternatives/emacs-48x48.png
# /etc/alternatives/lzcat.1.gz
# /etc/alternatives/mpifort.1.gz
# /etc/alternatives/ex.pl.1.gz
# /etc/alternatives/xdvi.bin
# /etc/alternatives/rvim
# /etc/alternatives/view.1.gz
# /etc/alternatives/lzfgrep
# /etc/alternatives/mpic++.1.gz
# /etc/alternatives/editor.1.gz
# /etc/alternatives/mpiexec
# /etc/alternatives/mpi
# /etc/alternatives/lzegrep
# /etc/alternatives/vi.pl.1.gz
# /etc/alternatives/lzcmp.1.gz
# /etc/alternatives/jed-script.1.gz
# /etc/alternatives/grep-changelog.1.gz
# /etc/alternatives/mpicc.1.gz
# /etc/alternatives/ex.fr.1.gz
# /etc/alternatives/mpifort
# /etc/alternatives/etags.1.gz
# /etc/alternatives/emacs.1.gz
# /etc/alternatives/grep-changelog
# /etc/alternatives/mpicxx.1.gz
# /etc/alternatives/emacsclient.1.gz
# /etc/alternatives/lzless
# /etc/alternatives/mpi-fort.pc
# /etc/alternatives/vi.ru.1.gz
# /etc/alternatives/from.1.gz
# /etc/alternatives/x86_64-linux-gnu_xorg_extra_modules
# /etc/alternatives/x86_64-linux-gnu_gl_conf
# /etc/alternatives/from
# /etc/alternatives/write.1.gz
# /etc/alternatives/write
# /etc/sysctl.conf
# /etc/selinux/
# /etc/selinux/semanage.conf
# /etc/issue.net
# /etc/insserv.conf
# /etc/pam.d/
# /etc/pam.d/su
# /etc/pam.d/common-account
# /etc/pam.d/chfn
# /etc/pam.d/runuser
# /etc/pam.d/common-session
# /etc/pam.d/other
# /etc/pam.d/login
# /etc/pam.d/chsh
# /etc/pam.d/runuser-l
# /etc/pam.d/passwd
# /etc/pam.d/common-auth
# /etc/pam.d/systemd-user
# /etc/pam.d/common-session-noninteractive
# /etc/pam.d/common-password
# /etc/pam.d/newusers
# /etc/pam.d/chpasswd
# /etc/pam.d/cron
# /etc/pam.d/sudo
# /etc/machine-id
# /etc/debconf.conf
# /etc/apt/
# /etc/apt/auth.conf.d/
# /etc/apt/preferences.d/
# /etc/apt/sources.list.d/
# /etc/apt/sources.list.d/heroku.list
# /etc/apt/sources.list.d/cassandra.sources.list
# /etc/apt/sources.list.d/nodesource.list
# /etc/apt/sources.list.d/ubuntu-toolchain-r-ubuntu-test-xenial.list
# /etc/apt/trusted.gpg.d/
# /etc/apt/trusted.gpg.d/ubuntu-toolchain-r_ubuntu_test.gpg
# /etc/apt/trusted.gpg.d/ubuntu-toolchain-r_ubuntu_test.gpg~
# /etc/apt/apt.conf.d/
# /etc/apt/apt.conf.d/01-vendor-ubuntu
# /etc/apt/apt.conf.d/01autoremove-kernels
# /etc/apt/apt.conf.d/01autoremove
# /etc/apt/apt.conf.d/70debconf
# /etc/apt/apt.conf.d/01autoremove-postgresql
# /etc/apt/apt.conf.d/docker-clean
# /etc/apt/apt.conf.d/docker-autoremove-suggests
# /etc/apt/apt.conf.d/docker-gzip-indexes
# /etc/apt/apt.conf.d/docker-no-languages
# /etc/apt/sources.list
# /etc/apt/trusted.gpg
# /etc/apt/trusted.gpg~
# /etc/apt/sources.list.save
# /etc/bash_completion.d/
# /etc/bash_completion.d/insserv
# /etc/bash_completion.d/git-prompt
# /etc/rc4.d/
# /etc/rc4.d/README
# /etc/rc4.d/S01cron
# /etc/rc4.d/S01postgresql
# /etc/rc4.d/S01sysstat
# /etc/rc4.d/S03rc.local
# /etc/rc4.d/S03ondemand
# /etc/rc4.d/S01ntp
# /etc/rc4.d/S02cassandra
# /etc/rc4.d/S01dbus
# /etc/rc2.d/
# /etc/rc2.d/README
# /etc/rc2.d/S01cron
# /etc/rc2.d/S01postgresql
# /etc/rc2.d/S01sysstat
# /etc/rc2.d/S03rc.local
# /etc/rc2.d/S03ondemand
# /etc/rc2.d/S01ntp
# /etc/rc2.d/S02cassandra
# /etc/rc2.d/S01dbus
# /etc/issue
# /etc/cron.daily/
# /etc/cron.daily/apt-compat
# /etc/cron.daily/dpkg
# /etc/cron.daily/passwd
# /etc/cron.daily/sysstat
# /etc/cron.daily/logrotate
# /etc/cron.daily/.placeholder
# /etc/cron.daily/ntp
# /etc/cron.daily/bsdmainutils
# /etc/cron.daily/man-db
# /etc/deluser.conf
# /etc/passwd
# /etc/shadow
# /etc/ld.so.conf.d/
# /etc/ld.so.conf.d/libc.conf
# /etc/ld.so.conf.d/x86_64-linux-gnu.conf
# /etc/ld.so.conf.d/x86_64-linux-gnu_EGL.conf
# /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf
# /etc/update-motd.d/
# /etc/update-motd.d/10-help-text
# /etc/update-motd.d/00-header
# /etc/update-motd.d/50-motd-news
# /etc/mke2fs.conf
# /etc/resolv.conf
# /etc/libaudit.conf
# /etc/subuid
# /etc/opt/
# /etc/shells
# /etc/rc5.d/
# /etc/rc5.d/README
# /etc/rc5.d/S01cron
# /etc/rc5.d/S01postgresql
# /etc/rc5.d/S01sysstat
# /etc/rc5.d/S03rc.local
# /etc/rc5.d/S03ondemand
# /etc/rc5.d/S01ntp
# /etc/rc5.d/S02cassandra
# /etc/rc5.d/S01dbus
# /etc/rcS.d/
# /etc/rcS.d/S08mountall-bootclean.sh
# /etc/rcS.d/S01hostname.sh
# /etc/rcS.d/S01mountkernfs.sh
# /etc/rcS.d/S04checkroot.sh
# /etc/rcS.d/S07mountall.sh
# /etc/rcS.d/S02procps
# /etc/rcS.d/S06checkroot-bootclean.sh
# /etc/rcS.d/S02mountdevsubfs.sh
# /etc/rcS.d/README
# /etc/rcS.d/S05checkfs.sh
# /etc/rcS.d/S03hwclock.sh
# /etc/rcS.d/S06urandom
# /etc/rcS.d/S10bootmisc.sh
# /etc/rcS.d/S08mountnfs.sh
# /etc/rcS.d/S09mountnfs-bootclean.sh
# /etc/rcS.d/S07networking
# /etc/rcS.d/S01x11-common
# /etc/gai.conf
# /etc/hostname
# /etc/pam.conf
# /etc/mtab
# /etc/insserv.conf.d/
# /etc/lsb-release
# /etc/rc1.d/
# /etc/rc1.d/S01killprocs
# /etc/rc1.d/S02single
# /etc/rc1.d/README
# /etc/rc1.d/K01postgresql
# /etc/rc1.d/K01cassandra
# /etc/rc1.d/K02ntp
# /etc/default/
# /etc/default/rcS
# /etc/default/halt
# /etc/default/devpts
# /etc/default/useradd
# /etc/default/motd-news
# /etc/default/nss
# /etc/default/sysstat
# /etc/default/cron
# /etc/default/cassandra
# /etc/default/ntp
# /etc/default/networking
# /etc/default/cacerts
# /etc/default/dbus
# /etc/default/bsdmainutils
# /etc/default/locale
# /etc/bash.bashrc
# /etc/binfmt.d/
# /etc/host.conf
# /etc/securetty
# /etc/.pwd.lock
# /etc/tmpfiles.d/
# /etc/init.d/
# /etc/init.d/ondemand
# /etc/init.d/rcS
# /etc/init.d/umountfs
# /etc/init.d/checkroot-bootclean.sh
# /etc/init.d/halt
# /etc/init.d/mountnfs-bootclean.sh
# /etc/init.d/killprocs
# /etc/init.d/umountnfs.sh
# /etc/init.d/.depend.boot
# /etc/init.d/skeleton
# /etc/init.d/sendsigs
# /etc/init.d/mountall.sh
# /etc/init.d/mountnfs.sh
# /etc/init.d/README
# /etc/init.d/reboot
# /etc/init.d/mountkernfs.sh
# /etc/init.d/single
# /etc/init.d/checkfs.sh
# /etc/init.d/.depend.start
# /etc/init.d/urandom
# /etc/init.d/umountroot
# /etc/init.d/mountdevsubfs.sh
# /etc/init.d/.depend.stop
# /etc/init.d/rc
# /etc/init.d/mountall-bootclean.sh
# /etc/init.d/procps
# /etc/init.d/bootmisc.sh
# /etc/init.d/rc.local
# /etc/init.d/hostname.sh
# /etc/init.d/checkroot.sh
# /etc/init.d/hwclock.sh
# /etc/init.d/sysstat
# /etc/init.d/postgresql
# /etc/init.d/cron
# /etc/init.d/cassandra
# /etc/init.d/ntp
# /etc/init.d/networking
# /etc/init.d/dbus
# /etc/init.d/x11-common
# /etc/rc.local
# /etc/xdg/
# /etc/xdg/systemd/
# /etc/xdg/systemd/user
# /etc/xdg/autostart/
# /etc/xdg/autostart/gsettings-data-convert.desktop
# /etc/timezone
# /etc/ld.so.conf
# /etc/rc0.d/
# /etc/rc0.d/K01urandom
# /etc/rc0.d/README
# /etc/rc0.d/K01postgresql
# /etc/rc0.d/K02hwclock.sh
# /etc/rc0.d/K01cassandra
# /etc/rc0.d/K03umountnfs.sh
# /etc/rc0.d/K05umountfs
# /etc/rc0.d/K06umountroot
# /etc/rc0.d/K02sendsigs
# /etc/rc0.d/K04networking
# /etc/rc0.d/K07halt
# /etc/ld.so.cache
# /etc/logrotate.conf
# /etc/sysstat/
# /etc/sysstat/sysstat
# /etc/sysstat/sysstat.ioconf
# /etc/group-
# /etc/passwd-
# /etc/postgresql/
# /etc/postgresql/9.5/
# /etc/postgresql/9.5/main/
# /etc/postgresql/9.5/main/postgresql.conf
# /etc/postgresql/9.5/main/environment
# /etc/postgresql/9.5/main/pg_ctl.conf
# /etc/postgresql/9.5/main/start.conf
# /etc/postgresql/9.5/main/pg_hba.conf
# /etc/postgresql/9.5/main/pg_ident.conf
# /etc/cron.hourly/
# /etc/cron.hourly/.placeholder
# /etc/cron.d/
# /etc/cron.d/sysstat
# /etc/cron.d/.placeholder
# /etc/postgresql-common/
# /etc/postgresql-common/root.crt
# /etc/postgresql-common/pg_upgradecluster.d/
# /etc/postgresql-common/createcluster.conf
# /etc/postgresql-common/user_clusters
# /etc/gshadow-
# /etc/shadow-
# /etc/crontab
# /etc/ssl/
# /etc/ssl/openssl.cnf
# /etc/ssl/private/
# /etc/ssl/private/ssl-cert-snakeoil.key
# /etc/ssl/certs/
# /etc/ssl/certs/d6e6eab9.0
# /etc/ssl/certs/AddTrust_Qualified_Certificates_Root.pem
# /etc/ssl/certs/9d520b32.0
# /etc/ssl/certs/ePKI_Root_Certification_Authority.pem
# /etc/ssl/certs/d4c339cb.0
# /etc/ssl/certs/5cf9d536.0
# /etc/ssl/certs/812e17de.0
# /etc/ssl/certs/062cdee6.0
# /etc/ssl/certs/d41b5e2a.0
# /etc/ssl/certs/TÜRKTRUST_Elektronik_Sertifika_Hizmet_Sağlayıcısı_H5.pem
# /etc/ssl/certs/f30dd6ad.0
# /etc/ssl/certs/5f47b495.0
# /etc/ssl/certs/ee64a828.0
# /etc/ssl/certs/2fa87019.0
# /etc/ssl/certs/32888f65.0
# /etc/ssl/certs/034868d6.0
# /etc/ssl/certs/Amazon_Root_CA_1.pem
# /etc/ssl/certs/5046c355.0
# /etc/ssl/certs/GlobalSign_Root_CA_-_R3.pem
# /etc/ssl/certs/Certum_Trusted_Network_CA.pem
# /etc/ssl/certs/Hellenic_Academic_and_Research_Institutions_RootCA_2011.pem
# /etc/ssl/certs/UTN_USERFirst_Hardware_Root_CA.pem
# /etc/ssl/certs/480720ec.0
# /etc/ssl/certs/fde84897.0
# /etc/ssl/certs/03179a64.0
# /etc/ssl/certs/40dc992e.0
# /etc/ssl/certs/a2c66da8.0
# /etc/ssl/certs/fb5fa911.0
# /etc/ssl/certs/Security_Communication_EV_RootCA1.pem
# /etc/ssl/certs/OpenTrust_Root_CA_G1.pem
# /etc/ssl/certs/ab5346f4.0
# /etc/ssl/certs/a760e1bd.0
# /etc/ssl/certs/9f533518.0
# /etc/ssl/certs/9479c8c3.0
# /etc/ssl/certs/TURKTRUST_Certificate_Services_Provider_Root_2007.pem
# /etc/ssl/certs/93bc0acc.0
# /etc/ssl/certs/3c6676aa.0
# /etc/ssl/certs/Secure_Global_CA.pem
# /etc/ssl/certs/7999be0d.0
# /etc/ssl/certs/7a7c655d.0
# /etc/ssl/certs/9c8dfbd4.0
# /etc/ssl/certs/8c24b137.0
# /etc/ssl/certs/Izenpe.com.pem
# /etc/ssl/certs/d7746a63.0
# /etc/ssl/certs/Swisscom_Root_CA_2.pem
# /etc/ssl/certs/87229d21.0
# /etc/ssl/certs/1f58a078.0
# /etc/ssl/certs/4be590e0.0
# /etc/ssl/certs/d8317ada.0
# /etc/ssl/certs/1e1eab7c.0
# /etc/ssl/certs/Camerfirma_Chambers_of_Commerce_Root.pem
# /etc/ssl/certs/450c6e38.0
# /etc/ssl/certs/f39fc864.0
# /etc/ssl/certs/e73d606e.0
# /etc/ssl/certs/DigiCert_Assured_ID_Root_G3.pem
# /etc/ssl/certs/2d9dafe4.0
# /etc/ssl/certs/124bbd54.0
# /etc/ssl/certs/02b73561.0
# /etc/ssl/certs/IdenTrust_Commercial_Root_CA_1.pem
# /etc/ssl/certs/1e08bfd1.0
# /etc/ssl/certs/67495436.0
# /etc/ssl/certs/87753b0d.0
# /etc/ssl/certs/aee5f10d.0
# /etc/ssl/certs/04f60c28.0
# /etc/ssl/certs/95aff9e3.0
# /etc/ssl/certs/b66938e9.0
# /etc/ssl/certs/ba89ed3b.0
# /etc/ssl/certs/QuoVadis_Root_CA_2.pem
# /etc/ssl/certs/5ad8a5d6.0
# /etc/ssl/certs/0d69c7e1.0
# /etc/ssl/certs/76faf6c0.0
# /etc/ssl/certs/7f3d5d1d.0
# /etc/ssl/certs/Global_Chambersign_Root_-_2008.pem
# /etc/ssl/certs/81b9768f.0
# /etc/ssl/certs/89c02a45.0
# /etc/ssl/certs/CNNIC_ROOT.pem
# /etc/ssl/certs/91739615.0
# /etc/ssl/certs/d16a5865.0
# /etc/ssl/certs/75d1b2ed.0
# /etc/ssl/certs/dbc54cab.0
# /etc/ssl/certs/eed8c118.0
# /etc/ssl/certs/3bde41ac.0
# /etc/ssl/certs/3929ec9f.0
# /etc/ssl/certs/b13cc6df.0
# /etc/ssl/certs/d7e8dc79.0
# /etc/ssl/certs/PSCProcert.pem
# /etc/ssl/certs/8d6437c3.0
# /etc/ssl/certs/VeriSign_Universal_Root_Certification_Authority.pem
# /etc/ssl/certs/7992b8bb.0
# /etc/ssl/certs/3d441de8.0
# /etc/ssl/certs/LuxTrust_Global_Root_2.pem
# /etc/ssl/certs/GlobalSign_Root_CA.pem
# /etc/ssl/certs/5cd81ad7.0
# /etc/ssl/certs/AddTrust_Low-Value_Services_Root.pem
# /etc/ssl/certs/ce5e74ef.0
# /etc/ssl/certs/c51c224c.0
# /etc/ssl/certs/3c58f906.0
# /etc/ssl/certs/e48193cf.0
# /etc/ssl/certs/ed39abd0.0
# /etc/ssl/certs/e36a6752.0
# /etc/ssl/certs/COMODO_Certification_Authority.pem
# /etc/ssl/certs/Starfield_Root_Certificate_Authority_-_G2.pem
# /etc/ssl/certs/Go_Daddy_Root_Certificate_Authority_-_G2.pem
# /etc/ssl/certs/790a7190.0
# /etc/ssl/certs/111e6273.0
# /etc/ssl/certs/e268a4c5.0
# /etc/ssl/certs/8160b96c.0
# /etc/ssl/certs/DST_ACES_CA_X6.pem
# /etc/ssl/certs/455f1b52.0
# /etc/ssl/certs/9007ae68.0
# /etc/ssl/certs/DigiCert_Assured_ID_Root_G2.pem
# /etc/ssl/certs/157753a5.0
# /etc/ssl/certs/Atos_TrustedRoot_2011.pem
# /etc/ssl/certs/064e0aa9.0
# /etc/ssl/certs/fd08c599.0
# /etc/ssl/certs/dc99f41e.0
# /etc/ssl/certs/Chambers_of_Commerce_Root_-_2008.pem
# /etc/ssl/certs/895cad1a.0
# /etc/ssl/certs/40193066.0
# /etc/ssl/certs/DigiCert_Trusted_Root_G4.pem
# /etc/ssl/certs/c491639e.0
# /etc/ssl/certs/56657bde.0
# /etc/ssl/certs/ISRG_Root_X1.pem
# /etc/ssl/certs/a2df7ad7.0
# /etc/ssl/certs/Swisscom_Root_CA_1.pem
# /etc/ssl/certs/GeoTrust_Primary_Certification_Authority.pem
# /etc/ssl/certs/c907e29b.0
# /etc/ssl/certs/27af790d.0
# /etc/ssl/certs/Entrust.net_Premium_2048_Secure_Server_CA.pem
# /etc/ssl/certs/4f316efb.0
# /etc/ssl/certs/a3896b44.0
# /etc/ssl/certs/GeoTrust_Universal_CA_2.pem
# /etc/ssl/certs/cc450945.0
# /etc/ssl/certs/Go_Daddy_Class_2_CA.pem
# /etc/ssl/certs/8d86cdd1.0
# /etc/ssl/certs/Certplus_Class_2_Primary_CA.pem
# /etc/ssl/certs/Amazon_Root_CA_4.pem
# /etc/ssl/certs/Staat_der_Nederlanden_Root_CA_-_G3.pem
# /etc/ssl/certs/592c0a9a.0
# /etc/ssl/certs/5f15c80c.0
# /etc/ssl/certs/cbeee9e2.0
# /etc/ssl/certs/3e7271e8.0
# /etc/ssl/certs/Network_Solutions_Certificate_Authority.pem
# /etc/ssl/certs/Verisign_Class_3_Public_Primary_Certification_Authority_-_G3.pem
# /etc/ssl/certs/a0bc6fbb.0
# /etc/ssl/certs/TeliaSonera_Root_CA_v1.pem
# /etc/ssl/certs/e775ed2d.0
# /etc/ssl/certs/23f4c490.0
# /etc/ssl/certs/d18e9066.0
# /etc/ssl/certs/ca-certificates.crt
# /etc/ssl/certs/b204d74a.0
# /etc/ssl/certs/SwissSign_Silver_CA_-_G2.pem
# /etc/ssl/certs/60afe812.0
# /etc/ssl/certs/bf64f35b.0
# /etc/ssl/certs/524d9b43.0
# /etc/ssl/certs/Comodo_AAA_Services_root.pem
# /etc/ssl/certs/8cb5ee0f.0
# /etc/ssl/certs/1dcd6f4c.0
# /etc/ssl/certs/COMODO_RSA_Certification_Authority.pem
# /etc/ssl/certs/GeoTrust_Primary_Certification_Authority_-_G3.pem
# /etc/ssl/certs/4e18c148.0
# /etc/ssl/certs/b1b8a7f3.0
# /etc/ssl/certs/219d9499.0
# /etc/ssl/certs/ff783690.0
# /etc/ssl/certs/Hellenic_Academic_and_Research_Institutions_ECC_RootCA_2015.pem
# /etc/ssl/certs/1676090a.0
# /etc/ssl/certs/3c860d51.0
# /etc/ssl/certs/d06393bb.0
# /etc/ssl/certs/1eb37bdf.0
# /etc/ssl/certs/T-TeleSec_GlobalRoot_Class_3.pem
# /etc/ssl/certs/2ae6433e.0
# /etc/ssl/certs/608a55ad.0
# /etc/ssl/certs/QuoVadis_Root_CA_2_G3.pem
# /etc/ssl/certs/1874d4aa.0
# /etc/ssl/certs/Cybertrust_Global_Root.pem
# /etc/ssl/certs/AffirmTrust_Networking.pem
# /etc/ssl/certs/dfc0fe80.0
# /etc/ssl/certs/E-Tugra_Certification_Authority.pem
# /etc/ssl/certs/00673b5b.0
# /etc/ssl/certs/DST_Root_CA_X3.pem
# /etc/ssl/certs/bdacca6f.0
# /etc/ssl/certs/b0ed035a.0
# /etc/ssl/certs/18856ac4.0
# /etc/ssl/certs/0d5a4e1c.0
# /etc/ssl/certs/3a3b02ce.0
# /etc/ssl/certs/b0e59380.0
# /etc/ssl/certs/de6d66f3.0
# /etc/ssl/certs/Entrust_Root_Certification_Authority_-_G2.pem
# /etc/ssl/certs/5a3f0ff8.0
# /etc/ssl/certs/2c11d503.0
# /etc/ssl/certs/2b349938.0
# /etc/ssl/certs/5443e9e3.0
# /etc/ssl/certs/6fcc125d.0
# /etc/ssl/certs/GeoTrust_Primary_Certification_Authority_-_G2.pem
# /etc/ssl/certs/QuoVadis_Root_CA_1_G3.pem
# /etc/ssl/certs/Microsec_e-Szigno_Root_CA_2009.pem
# /etc/ssl/certs/75680d2e.0
# /etc/ssl/certs/D-TRUST_Root_Class_3_CA_2_2009.pem
# /etc/ssl/certs/DigiCert_Global_Root_G2.pem
# /etc/ssl/certs/3513523f.0
# /etc/ssl/certs/cb59f961.0
# /etc/ssl/certs/9dbefe7b.0
# /etc/ssl/certs/Baltimore_CyberTrust_Root.pem
# /etc/ssl/certs/3e45d192.0
# /etc/ssl/certs/GlobalSign_ECC_Root_CA_-_R5.pem
# /etc/ssl/certs/988a38cb.0
# /etc/ssl/certs/2add47b6.0
# /etc/ssl/certs/106f3e4d.0
# /etc/ssl/certs/Certigna.pem
# /etc/ssl/certs/e113c810.0
# /etc/ssl/certs/2e5ac55d.0
# /etc/ssl/certs/381ce4dd.0
# /etc/ssl/certs/cd8c0d63.0
# /etc/ssl/certs/c90bc37d.0
# /etc/ssl/certs/b0f3e76e.0
# /etc/ssl/certs/a81e292b.0
# /etc/ssl/certs/b727005e.0
# /etc/ssl/certs/9168f543.0
# /etc/ssl/certs/3ad48a91.0
# /etc/ssl/certs/bc3f2570.0
# /etc/ssl/certs/7a819ef2.0
# /etc/ssl/certs/e2799e36.0
# /etc/ssl/certs/9282e51c.0
# /etc/ssl/certs/02265526.0
# /etc/ssl/certs/OpenTrust_Root_CA_G2.pem
# /etc/ssl/certs/ff34af3f.0
# /etc/ssl/certs/b7db1890.0
# /etc/ssl/certs/52b525c7.0
# /etc/ssl/certs/Certum_Root_CA.pem
# /etc/ssl/certs/57bcb2da.0
# /etc/ssl/certs/thawte_Primary_Root_CA.pem
# /etc/ssl/certs/9685a493.0
# /etc/ssl/certs/USERTrust_ECC_Certification_Authority.pem
# /etc/ssl/certs/ef954a4e.0
# /etc/ssl/certs/f081611a.0
# /etc/ssl/certs/OpenTrust_Root_CA_G3.pem
# /etc/ssl/certs/DigiCert_Global_Root_G3.pem
# /etc/ssl/certs/VeriSign_Class_3_Public_Primary_Certification_Authority_-_G4.pem
# /etc/ssl/certs/5a4d6896.0
# /etc/ssl/certs/ccc52f49.0
# /etc/ssl/certs/cbf06781.0
# /etc/ssl/certs/5c44d531.0
# /etc/ssl/certs/09789157.0
# /etc/ssl/certs/57692373.0
# /etc/ssl/certs/442adcac.0
# /etc/ssl/certs/ca6e4ad9.0
# /etc/ssl/certs/QuoVadis_Root_CA.pem
# /etc/ssl/certs/b872f2b4.0
# /etc/ssl/certs/3c9a4d3b.0
# /etc/ssl/certs/GeoTrust_Global_CA.pem
# /etc/ssl/certs/c5d3212a.0
# /etc/ssl/certs/Hongkong_Post_Root_CA_1.pem
# /etc/ssl/certs/def36a68.0
# /etc/ssl/certs/c28a8a30.0
# /etc/ssl/certs/d6325660.0
# /etc/ssl/certs/b7a5b843.0
# /etc/ssl/certs/9c3323d4.0
# /etc/ssl/certs/418595b9.0
# /etc/ssl/certs/AffirmTrust_Premium.pem
# /etc/ssl/certs/d4dae3dd.0
# /etc/ssl/certs/9339512a.0
# /etc/ssl/certs/OISTE_WISeKey_Global_Root_GB_CA.pem
# /etc/ssl/certs/052e396b.0
# /etc/ssl/certs/certSIGN_ROOT_CA.pem
# /etc/ssl/certs/c47d9980.0
# /etc/ssl/certs/128805a3.0
# /etc/ssl/certs/e18bfb83.0
# /etc/ssl/certs/ACCVRAIZ1.pem
# /etc/ssl/certs/607986c7.0
# /etc/ssl/certs/667c66d4.0
# /etc/ssl/certs/Autoridad_de_Certificacion_Firmaprofesional_CIF_A62634068.pem
# /etc/ssl/certs/thawte_Primary_Root_CA_-_G2.pem
# /etc/ssl/certs/5e4e69e7.0
# /etc/ssl/certs/cb156124.0
# /etc/ssl/certs/7d0b38bd.0
# /etc/ssl/certs/Buypass_Class_3_Root_CA.pem
# /etc/ssl/certs/IdenTrust_Public_Sector_Root_CA_1.pem
# /etc/ssl/certs/Starfield_Services_Root_Certificate_Authority_-_G2.pem
# /etc/ssl/certs/d59297b8.0
# /etc/ssl/certs/TÜBİTAK_UEKAE_Kök_Sertifika_Hizmet_Sağlayıcısı_-_Sürüm_3.pem
# /etc/ssl/certs/1dac3003.0
# /etc/ssl/certs/aeb67534.0
# /etc/ssl/certs/8b59b1ad.0
# /etc/ssl/certs/EC-ACC.pem
# /etc/ssl/certs/SwissSign_Gold_CA_-_G2.pem
# /etc/ssl/certs/D-TRUST_Root_Class_3_CA_2_EV_2009.pem
# /etc/ssl/certs/Security_Communication_RootCA2.pem
# /etc/ssl/certs/CA_Disig_Root_R1.pem
# /etc/ssl/certs/NetLock_Arany_=Class_Gold=_Főtanúsítvány.pem
# /etc/ssl/certs/OISTE_WISeKey_Global_Root_GA_CA.pem
# /etc/ssl/certs/6e8bf996.0
# /etc/ssl/certs/f387163d.0
# /etc/ssl/certs/Swisscom_Root_EV_CA_2.pem
# /etc/ssl/certs/USERTrust_RSA_Certification_Authority.pem
# /etc/ssl/certs/GeoTrust_Global_CA_2.pem
# /etc/ssl/certs/COMODO_ECC_Certification_Authority.pem
# /etc/ssl/certs/9d04f354.0
# /etc/ssl/certs/930ac5d2.0
# /etc/ssl/certs/4304c5e5.0
# /etc/ssl/certs/Amazon_Root_CA_2.pem
# /etc/ssl/certs/76579174.0
# /etc/ssl/certs/T-TeleSec_GlobalRoot_Class_2.pem
# /etc/ssl/certs/c0ff1f52.0
# /etc/ssl/certs/9c2e7d30.0
# /etc/ssl/certs/85cde254.0
# /etc/ssl/certs/21855f49.0
# /etc/ssl/certs/749e9e03.0
# /etc/ssl/certs/349f2832.0
# /etc/ssl/certs/Buypass_Class_2_Root_CA.pem
# /etc/ssl/certs/1df5a75f.0
# /etc/ssl/certs/GeoTrust_Universal_CA.pem
# /etc/ssl/certs/343eb6cb.0
# /etc/ssl/certs/EE_Certification_Centre_Root_CA.pem
# /etc/ssl/certs/cb1c3204.0
# /etc/ssl/certs/1636090b.0
# /etc/ssl/certs/Amazon_Root_CA_3.pem
# /etc/ssl/certs/SZAFIR_ROOT_CA2.pem
# /etc/ssl/certs/706f604c.0
# /etc/ssl/certs/dd8e9d41.0
# /etc/ssl/certs/7719f463.0
# /etc/ssl/certs/2e4eed3c.0
# /etc/ssl/certs/c01cdfa2.0
# /etc/ssl/certs/c089bbbd.0
# /etc/ssl/certs/facacbc6.0
# /etc/ssl/certs/02756ea4.0
# /etc/ssl/certs/Visa_eCommerce_Root.pem
# /etc/ssl/certs/c7e2a638.0
# /etc/ssl/certs/6b99d060.0
# /etc/ssl/certs/4042bcee.0
# /etc/ssl/certs/TUBITAK_Kamu_SM_SSL_Kok_Sertifikasi_-_Surum_1.pem
# /etc/ssl/certs/10531352.0
# /etc/ssl/certs/Starfield_Class_2_CA.pem
# /etc/ssl/certs/e8de2f56.0
# /etc/ssl/certs/65b876bd.0
# /etc/ssl/certs/Security_Communication_Root_CA.pem
# /etc/ssl/certs/CA_Disig_Root_R2.pem
# /etc/ssl/certs/9576d26b.0
# /etc/ssl/certs/7672ac4b.0
# /etc/ssl/certs/8867006a.0
# /etc/ssl/certs/31188b5e.0
# /etc/ssl/certs/9d6523ce.0
# /etc/ssl/certs/244b5494.0
# /etc/ssl/certs/Certplus_Root_CA_G2.pem
# /etc/ssl/certs/63a2c897.0
# /etc/ssl/certs/e536d871.0
# /etc/ssl/certs/GlobalSign_Root_CA_-_R2.pem
# /etc/ssl/certs/Staat_der_Nederlanden_Root_CA_-_G2.pem
# /etc/ssl/certs/thawte_Primary_Root_CA_-_G3.pem
# /etc/ssl/certs/DigiCert_Global_Root_CA.pem
# /etc/ssl/certs/SecureTrust_CA.pem
# /etc/ssl/certs/AffirmTrust_Commercial.pem
# /etc/ssl/certs/Deutsche_Telekom_Root_CA_2.pem
# /etc/ssl/certs/b936d1c6.0
# /etc/ssl/certs/d853d49e.0
# /etc/ssl/certs/559f7c71.0
# /etc/ssl/certs/Certplus_Root_CA_G1.pem
# /etc/ssl/certs/SecureSign_RootCA11.pem
# /etc/ssl/certs/DigiCert_Assured_ID_Root_CA.pem
# /etc/ssl/certs/40547a79.0
# /etc/ssl/certs/DigiCert_High_Assurance_EV_Root_CA.pem
# /etc/ssl/certs/6187b673.0
# /etc/ssl/certs/48a195d8.0
# /etc/ssl/certs/ea169617.0
# /etc/ssl/certs/ACEDICOM_Root.pem
# /etc/ssl/certs/a7605362.0
# /etc/ssl/certs/QuoVadis_Root_CA_3_G3.pem
# /etc/ssl/certs/XRamp_Global_CA_Root.pem
# /etc/ssl/certs/399e7759.0
# /etc/ssl/certs/TWCA_Root_Certification_Authority.pem
# /etc/ssl/certs/1e09d511.0
# /etc/ssl/certs/Entrust_Root_Certification_Authority_-_EC1.pem
# /etc/ssl/certs/653b494a.0
# /etc/ssl/certs/Comodo_Secure_Services_root.pem
# /etc/ssl/certs/0b1b94ef.0
# /etc/ssl/certs/69105f4f.0
# /etc/ssl/certs/cd58d51e.0
# /etc/ssl/certs/Entrust_Root_Certification_Authority.pem
# /etc/ssl/certs/QuoVadis_Root_CA_3.pem
# /etc/ssl/certs/China_Internet_Network_Information_Center_EV_Certificates_Root.pem
# /etc/ssl/certs/861a399d.0
# /etc/ssl/certs/6410666e.0
# /etc/ssl/certs/Actalis_Authentication_Root_CA.pem
# /etc/ssl/certs/3efd4dc0.0
# /etc/ssl/certs/1d3472b9.0
# /etc/ssl/certs/080911ac.0
# /etc/ssl/certs/fe8a2cd8.0
# /etc/ssl/certs/Comodo_Trusted_Services_root.pem
# /etc/ssl/certs/b1159c4c.0
# /etc/ssl/certs/Taiwan_GRCA.pem
# /etc/ssl/certs/Certum_Trusted_Network_CA_2.pem
# /etc/ssl/certs/f3377b1b.0
# /etc/ssl/certs/5273a94c.0
# /etc/ssl/certs/VeriSign_Class_3_Public_Primary_Certification_Authority_-_G5.pem
# /etc/ssl/certs/Certinomis_-_Autorité_Racine.pem
# /etc/ssl/certs/4a6481c9.0
# /etc/ssl/certs/c9f83a1c.0
# /etc/ssl/certs/17b51fe6.0
# /etc/ssl/certs/e8651083.0
# /etc/ssl/certs/TWCA_Global_Root_CA.pem
# /etc/ssl/certs/Hellenic_Academic_and_Research_Institutions_RootCA_2015.pem
# /etc/ssl/certs/d66b55d9.0
# /etc/ssl/certs/2c543cd1.0
# /etc/ssl/certs/76cb8f92.0
# /etc/ssl/certs/9f0f5fd6.0
# /etc/ssl/certs/ee7cd6fb.0
# /etc/ssl/certs/882de061.0
# /etc/ssl/certs/35105088.0
# /etc/ssl/certs/116bf586.0
# /etc/ssl/certs/86212b19.0
# /etc/ssl/certs/bd1910d4.0
# /etc/ssl/certs/0c4c9b6c.0
# /etc/ssl/certs/9772ca32.0
# /etc/ssl/certs/4bfab552.0
# /etc/ssl/certs/Trustis_FPS_Root_CA.pem
# /etc/ssl/certs/12d55845.0
# /etc/ssl/certs/AddTrust_Public_Services_Root.pem
# /etc/ssl/certs/9ab62355.0
# /etc/ssl/certs/Staat_der_Nederlanden_EV_Root_CA.pem
# /etc/ssl/certs/GlobalSign_ECC_Root_CA_-_R4.pem
# /etc/ssl/certs/AddTrust_External_Root.pem
# /etc/ssl/certs/1e8e7201.0
# /etc/ssl/certs/b3fb433b.0
# /etc/ssl/certs/d957f522.0
# /etc/ssl/certs/7d453d8f.0
# /etc/ssl/certs/cf701eeb.0
# /etc/ssl/certs/82223c44.0
# /etc/ssl/certs/Sonera_Class_2_Root_CA.pem
# /etc/ssl/certs/AffirmTrust_Premium_ECC.pem
# /etc/ssl/certs/a94d09e5.0
# /etc/ssl/certs/a7d2cf64.0
# /etc/ssl/certs/AC_RAIZ_FNMT-RCM.pem
# /etc/ssl/certs/54657681.0
# /etc/ssl/certs/48bec511.0
# /etc/ssl/certs/f060240e.0
# /etc/ssl/certs/e442e424.0
# /etc/ssl/certs/CFCA_EV_ROOT.pem
# /etc/ssl/certs/Certinomis_-_Root_CA.pem
# /etc/ssl/certs/451b5485.0
# /etc/ssl/certs/e60bf0c0.0
# /etc/ssl/certs/f90208f7.0
# /etc/ssl/certs/ad088e1d.0
# /etc/ssl/certs/Camerfirma_Global_Chambersign_Root.pem
# /etc/ssl/certs/6d41d539.0
# /etc/ssl/certs/5a250ea7.0
# /etc/ssl/certs/fc5a8f99.0
# /etc/ssl/certs/ssl-cert-snakeoil.pem
# /etc/ssl/certs/d301ca2e
# /etc/ssl/certs/java/
# /etc/ssl/certs/java/cacerts
# /etc/cron.monthly/
# /etc/cron.monthly/.placeholder
# /etc/services
# /etc/network/
# /etc/network/if-down.d/
# /etc/network/if-down.d/upstart
# /etc/network/interfaces
# /etc/network/interfaces.d/
# /etc/network/if-pre-up.d/
# /etc/network/if-post-down.d/
# /etc/network/if-up.d/
# /etc/network/if-up.d/upstart
# /etc/apparmor/
# /etc/apparmor/init/
# /etc/apparmor/init/network-interface-security/
# /etc/apparmor/init/network-interface-security/sbin.dhclient
# /etc/apparmor/init/network-interface-security/usr.sbin.ntpd
# /etc/rpc
# /etc/iproute2/
# /etc/iproute2/rt_tables
# /etc/iproute2/group
# /etc/iproute2/nl_protos
# /etc/iproute2/rt_dsfield
# /etc/iproute2/ematch_map
# /etc/iproute2/rt_protos
# /etc/iproute2/rt_realms
# /etc/iproute2/rt_scopes
# /etc/cassandra/
# /etc/cassandra/logback.xml
# /etc/cassandra/jvm.options
# /etc/cassandra/cassandra-rackdc.properties
# /etc/cassandra/hotspot_compiler
# /etc/cassandra/logback-tools.xml
# /etc/cassandra/triggers/
# /etc/cassandra/triggers/README.txt
# /etc/cassandra/commitlog_archiving.properties
# /etc/cassandra/cassandra.yaml
# /etc/cassandra/cassandra-env.sh
# /etc/cassandra/cassandra-topology.properties
# /etc/protocols
# /etc/ntp.conf
# /etc/apparmor.d/
# /etc/apparmor.d/sbin.dhclient
# /etc/apparmor.d/local/
# /etc/apparmor.d/local/sbin.dhclient
# /etc/apparmor.d/local/usr.sbin.ntpd
# /etc/apparmor.d/force-complain/
# /etc/apparmor.d/usr.sbin.ntpd
# /etc/apparmor.d/tunables/
# /etc/apparmor.d/tunables/ntpd
# /etc/ca-certificates/
# /etc/ca-certificates/update.d/
# /etc/ca-certificates/update.d/jks-keystore
# /etc/mailcap
# /etc/.java/
# /etc/.java/.systemPrefs/
# /etc/.java/.systemPrefs/.system.lock
# /etc/.java/.systemPrefs/.systemRootModFile
# /etc/pki/
# /etc/pki/nssdb
# /etc/java-8-openjdk/
# /etc/java-8-openjdk/flavormap.properties
# /etc/java-8-openjdk/images/
# /etc/java-8-openjdk/images/cursors/
# /etc/java-8-openjdk/images/cursors/cursors.properties
# /etc/java-8-openjdk/psfontj2d.properties
# /etc/java-8-openjdk/net.properties
# /etc/java-8-openjdk/security/
# /etc/java-8-openjdk/security/nss.cfg
# /etc/java-8-openjdk/security/java.security
# /etc/java-8-openjdk/security/java.policy
# /etc/java-8-openjdk/security/blacklisted.certs
# /etc/java-8-openjdk/calendars.properties
# /etc/java-8-openjdk/management/
# /etc/java-8-openjdk/management/jmxremote.password
# /etc/java-8-openjdk/management/snmp.acl
# /etc/java-8-openjdk/management/management.properties
# /etc/java-8-openjdk/management/jmxremote.access
# /etc/java-8-openjdk/logging.properties
# /etc/java-8-openjdk/psfont.properties.ja
# /etc/java-8-openjdk/sound.properties
# /etc/java-8-openjdk/content-types.properties
# /etc/java-8-openjdk/swing.properties
# /etc/java-8-openjdk/jvm-amd64.cfg
# /etc/gconf/
# /etc/gconf/gconf.xml.mandatory/
# /etc/gconf/gconf.xml.mandatory/%gconf-tree.xml
# /etc/gconf/2/
# /etc/gconf/2/path
# /etc/gconf/2/evoldap.conf
# /etc/gconf/gconf.xml.defaults/
# /etc/gconf/gconf.xml.defaults/%gconf-tree.xml
# /etc/python/
# /etc/python/debian_config
# /etc/ghostscript/
# /etc/ghostscript/cidfmap.d/
# /etc/ghostscript/cidfmap.d/90gs-cjk-resource-japan2.conf
# /etc/ghostscript/cidfmap.d/90gs-cjk-resource-gb1.conf
# /etc/ghostscript/cidfmap.d/90gs-cjk-resource-korea1.conf
# /etc/ghostscript/cidfmap.d/90gs-cjk-resource-japan1.conf
# /etc/ghostscript/cidfmap.d/90gs-cjk-resource-cns1.conf
# /etc/papersize
# /etc/jed.d/
# /etc/jed.d/README
# /etc/jed.d/05jed-common.sl
# /etc/hosts.deny
# /etc/gtk-2.0/
# /etc/gtk-2.0/im-multipress.conf
# /etc/emacs24/
# /etc/emacs24/site-start.d/
# /etc/emacs24/site-start.d/00debian-vars.el
# /etc/emacs24/site-start.d/00debian-vars.elc
# /etc/texmf/
# /etc/texmf/dvips/
# /etc/texmf/dvips/config/
# /etc/texmf/tex/
# /etc/texmf/tex/generic/
# /etc/texmf/tex/generic/config/
# /etc/texmf/texdoctk/
# /etc/texmf/texdoctk/texdocrc.defaults
# /etc/texmf/texmf.d/
# /etc/texmf/texmf.d/00debian.cnf
# /etc/texmf/dvipdfmx/
# /etc/texmf/web2c/
# /etc/texmf/web2c/texmf.cnf
# /etc/texmf/web2c/mktex.cnf
# /etc/dictionaries-common/
# /etc/dictionaries-common/ispell-default
# /etc/gnome-vfs-2.0/
# /etc/gnome-vfs-2.0/modules/
# /etc/gnome-vfs-2.0/modules/default-modules.conf
# /etc/python2.7/
# /etc/python2.7/sitecustomize.py
# /etc/vim/
# /etc/vim/vimrc
# /etc/ucf.conf
# /etc/libpaper.d/
# /etc/libpaper.d/texlive-base
# /etc/ffserver.conf
# /etc/vdpau_wrapper.cfg
# /etc/perl/
# /etc/perl/CPAN/
# /etc/perl/Net/
# /etc/perl/Net/libnet.cfg
# /etc/gtk-3.0/
# /etc/gtk-3.0/settings.ini
# /etc/gtk-3.0/im-multipress.conf
# /etc/slsh.rc
# /etc/emacs/
# /etc/emacs/site-start.d/
# /etc/emacs/site-start.d/50cmake-data.el
# /etc/emacs/site-start.d/00debian-vars.el
# /etc/emacs/site-start.d/50dictionaries-common.el
# /etc/emacs/site-start.el
# /etc/openmpi/
# /etc/openmpi/openmpi-totalview.tcl
# /etc/openmpi/openmpi-default-hostfile
# /etc/openmpi/openmpi-mca-params.conf
# /etc/openal/
# /etc/openal/alsoft.conf
# /etc/hosts.allow
# /etc/ImageMagick-6/
# /etc/ImageMagick-6/mime.xml
# /etc/ImageMagick-6/policy.xml
# /etc/ImageMagick-6/magic.xml
# /etc/ImageMagick-6/type-dejavu.xml
# /etc/ImageMagick-6/delegates.xml
# /etc/ImageMagick-6/type.xml
# /etc/ImageMagick-6/coder.xml
# /etc/ImageMagick-6/colors.xml
# /etc/ImageMagick-6/type-ghostscript.xml
# /etc/ImageMagick-6/log.xml
# /etc/ImageMagick-6/quantization-table.xml
# /etc/ImageMagick-6/thresholds.xml
# /etc/ImageMagick-6/type-windows.xml
# /etc/fonts/
# /etc/fonts/conf.d/
# /etc/fonts/conf.d/51-local.conf
# /etc/fonts/conf.d/20-unhint-small-dejavu-serif.conf
# /etc/fonts/conf.d/58-dejavu-lgc-serif.conf
# /etc/fonts/conf.d/11-lcdfilter-default.conf
# /etc/fonts/conf.d/69-unifont.conf
# /etc/fonts/conf.d/20-unhint-small-dejavu-lgc-sans.conf
# /etc/fonts/conf.d/30-0-google-crosextra-carlito-fontconfig.conf
# /etc/fonts/conf.d/30-urw-aliases.conf
# /etc/fonts/conf.d/70-no-bitmaps.conf
# /etc/fonts/conf.d/80-delicious.conf
# /etc/fonts/conf.d/65-fonts-lmodern.conf
# /etc/fonts/conf.d/65-nonlatin.conf
# /etc/fonts/conf.d/50-user.conf
# /etc/fonts/conf.d/20-unhint-small-dejavu-lgc-sans-mono.conf
# /etc/fonts/conf.d/60-latin.conf
# /etc/fonts/conf.d/90-fonts-linux-libertine.conf
# /etc/fonts/conf.d/README
# /etc/fonts/conf.d/57-dejavu-serif.conf
# /etc/fonts/conf.d/45-latin.conf
# /etc/fonts/conf.d/30-metric-aliases.conf
# /etc/fonts/conf.d/30-0-google-crosextra-caladea-fontconfig.conf
# /etc/fonts/conf.d/65-fonts-persian.conf
# /etc/fonts/conf.d/10-antialias.conf
# /etc/fonts/conf.d/10-hinting-slight.conf
# /etc/fonts/conf.d/10-hinting.conf
# /etc/fonts/conf.d/20-unhint-small-dejavu-sans.conf
# /etc/fonts/conf.d/20-unhint-small-dejavu-lgc-serif.conf
# /etc/fonts/conf.d/58-dejavu-lgc-sans-mono.conf
# /etc/fonts/conf.d/20-unhint-small-vera.conf
# /etc/fonts/conf.d/10-scale-bitmap-fonts.conf
# /etc/fonts/conf.d/90-synthetic.conf
# /etc/fonts/conf.d/57-dejavu-sans-mono.conf
# /etc/fonts/conf.d/58-dejavu-lgc-sans.conf
# /etc/fonts/conf.d/20-unhint-small-dejavu-sans-mono.conf
# /etc/fonts/conf.d/40-nonlatin.conf
# /etc/fonts/conf.d/49-sansserif.conf
# /etc/fonts/conf.d/57-dejavu-sans.conf
# /etc/fonts/fonts.conf
# /etc/fonts/conf.avail/
# /etc/fonts/conf.avail/11-lcdfilter-legacy.conf
# /etc/fonts/conf.avail/10-sub-pixel-vrgb.conf
# /etc/fonts/conf.avail/51-local.conf
# /etc/fonts/conf.avail/20-unhint-small-dejavu-serif.conf
# /etc/fonts/conf.avail/65-khmer.conf
# /etc/fonts/conf.avail/58-dejavu-lgc-serif.conf
# /etc/fonts/conf.avail/70-force-bitmaps.conf
# /etc/fonts/conf.avail/10-sub-pixel-vbgr.conf
# /etc/fonts/conf.avail/11-lcdfilter-default.conf
# /etc/fonts/conf.avail/69-unifont.conf
# /etc/fonts/conf.avail/20-unhint-small-dejavu-lgc-sans.conf
# /etc/fonts/conf.avail/30-0-google-crosextra-carlito-fontconfig.conf
# /etc/fonts/conf.avail/30-urw-aliases.conf
# /etc/fonts/conf.avail/70-no-bitmaps.conf
# /etc/fonts/conf.avail/70-yes-bitmaps.conf
# /etc/fonts/conf.avail/80-delicious.conf
# /etc/fonts/conf.avail/10-unhinted.conf
# /etc/fonts/conf.avail/10-no-sub-pixel.conf
# /etc/fonts/conf.avail/65-fonts-lmodern.conf
# /etc/fonts/conf.avail/65-nonlatin.conf
# /etc/fonts/conf.avail/10-hinting-medium.conf
# /etc/fonts/conf.avail/50-user.conf
# /etc/fonts/conf.avail/20-unhint-small-dejavu-lgc-sans-mono.conf
# /etc/fonts/conf.avail/60-latin.conf
# /etc/fonts/conf.avail/90-fonts-linux-libertine.conf
# /etc/fonts/conf.avail/57-dejavu-serif.conf
# /etc/fonts/conf.avail/62-google-crosextra-caladea-fontconfig.conf
# /etc/fonts/conf.avail/45-latin.conf
# /etc/fonts/conf.avail/25-unhint-nonlatin.conf
# /etc/fonts/conf.avail/30-metric-aliases.conf
# /etc/fonts/conf.avail/30-0-google-crosextra-caladea-fontconfig.conf
# /etc/fonts/conf.avail/53-monospace-lcd-filter.conf
# /etc/fonts/conf.avail/65-fonts-persian.conf
# /etc/fonts/conf.avail/10-antialias.conf
# /etc/fonts/conf.avail/10-hinting-slight.conf
# /etc/fonts/conf.avail/10-hinting.conf
# /etc/fonts/conf.avail/20-unhint-small-dejavu-sans.conf
# /etc/fonts/conf.avail/11-lcdfilter-light.conf
# /etc/fonts/conf.avail/20-unhint-small-dejavu-lgc-serif.conf
# /etc/fonts/conf.avail/58-dejavu-lgc-sans-mono.conf
# /etc/fonts/conf.avail/20-unhint-small-vera.conf
# /etc/fonts/conf.avail/10-scale-bitmap-fonts.conf
# /etc/fonts/conf.avail/10-sub-pixel-rgb.conf
# /etc/fonts/conf.avail/10-sub-pixel-bgr.conf
# /etc/fonts/conf.avail/90-synthetic.conf
# /etc/fonts/conf.avail/57-dejavu-sans-mono.conf
# /etc/fonts/conf.avail/10-autohint.conf
# /etc/fonts/conf.avail/58-dejavu-lgc-sans.conf
# /etc/fonts/conf.avail/20-unhint-small-dejavu-sans-mono.conf
# /etc/fonts/conf.avail/62-google-crosextra-carlito-fontconfig.conf
# /etc/fonts/conf.avail/40-nonlatin.conf
# /etc/fonts/conf.avail/10-hinting-full.conf
# /etc/fonts/conf.avail/49-sansserif.conf
# /etc/fonts/conf.avail/57-dejavu-sans.conf
# /etc/pulse/
# /etc/pulse/client.conf
# /etc/locale.gen
# /etc/mime.types
# /etc/sudoers
# /etc/ldap/
# /etc/ldap/ldap.conf
# /etc/drirc
# /etc/mailcap.order
# /etc/sensors3.conf
# /etc/python3.5/
# /etc/python3.5/sitecustomize.py
# /etc/sudoers.d/
# /etc/sudoers.d/README
# /etc/sensors.d/
# /etc/sensors.d/.placeholder
# /etc/manpath.config
# /etc/calendar/
# /etc/calendar/default
# ...
# /usr/share/doc/libc-bin/copyright
# /usr/share/doc/libc-bin/changelog.Debian.gz
# /usr/share/doc/initscripts/
# /usr/share/doc/initscripts/README.Debian
# /usr/share/doc/initscripts/NEWS.Debian.gz
# /usr/share/doc/initscripts/copyright
# /usr/share/doc/initscripts/changelog.Debian.gz
# /usr/share/doc/libblkid1/
# /usr/share/doc/libblkid1/copyright
# /usr/share/doc/libblkid1/changelog.Debian.gz
# /usr/share/doc/libdebconfclient0/
# /usr/share/doc/libdebconfclient0/changelog.gz
# /usr/share/doc/libdebconfclient0/copyright
# /usr/share/doc/e2fsprogs/
# /usr/share/doc/e2fsprogs/RELEASE-NOTES.gz
# /usr/share/doc/e2fsprogs/README
# /usr/share/doc/e2fsprogs/copyright
# /usr/share/doc/e2fsprogs/changelog.Debian.gz
# /usr/share/doc/libacl1/
# /usr/share/doc/libacl1/copyright
# /usr/share/doc/libacl1/changelog.Debian.gz
# /usr/share/doc/passwd/
# /usr/share/doc/passwd/NEWS.gz
# /usr/share/doc/passwd/TODO.Debian
# /usr/share/doc/passwd/README.Debian
# /usr/share/doc/passwd/NEWS.Debian.gz
# /usr/share/doc/passwd/README
# /usr/share/doc/passwd/copyright
# /usr/share/doc/passwd/changelog.Debian.gz
# /usr/share/doc/passwd/TODO.gz
# /usr/share/doc/passwd/examples/
# /usr/share/doc/passwd/examples/passwd.expire.cron
# /usr/share/doc/util-linux/
# /usr/share/doc/util-linux/getopt_changelog.txt
# /usr/share/doc/util-linux/poeigl.txt.gz
# /usr/share/doc/util-linux/howto-usage-function.txt.gz
# /usr/share/doc/util-linux/pg.txt
# /usr/share/doc/util-linux/howto-pull-request.txt.gz
# /usr/share/doc/util-linux/howto-build-sys.txt
# /usr/share/doc/util-linux/mount.txt
# /usr/share/doc/util-linux/source-code-management.txt
# /usr/share/doc/util-linux/col.txt
# /usr/share/doc/util-linux/releases/
# /usr/share/doc/util-linux/releases/v2.18-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.26-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.16-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.27.1-ReleaseNotes
# /usr/share/doc/util-linux/releases/v2.27-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.21-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.15-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.13-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.24-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.17-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.23-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.20-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.19-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.25-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.22-ReleaseNotes.gz
# /usr/share/doc/util-linux/releases/v2.14-ReleaseNotes.gz
# /usr/share/doc/util-linux/howto-man-page.txt.gz
# /usr/share/doc/util-linux/howto-compilation.txt
# /usr/share/doc/util-linux/NEWS.Debian.gz
# /usr/share/doc/util-linux/howto-contribute.txt.gz
# /usr/share/doc/util-linux/AUTHORS.gz
# /usr/share/doc/util-linux/blkid.txt
# /usr/share/doc/util-linux/00-about-docs.txt
# /usr/share/doc/util-linux/cal.txt
# /usr/share/doc/util-linux/release-schedule.txt
# /usr/share/doc/util-linux/howto-debug.txt
# /usr/share/doc/util-linux/copyright
# /usr/share/doc/util-linux/modems-with-agetty.txt
# /usr/share/doc/util-linux/changelog.Debian.gz
# /usr/share/doc/util-linux/hwclock.txt
# /usr/share/doc/util-linux/howto-tests.txt
# /usr/share/doc/util-linux/getopt.txt
# /usr/share/doc/util-linux/PAM-configuration.txt
# /usr/share/doc/util-linux/deprecated.txt
# /usr/share/doc/util-linux/examples/
# /usr/share/doc/util-linux/examples/fstab
# /usr/share/doc/util-linux/examples/fstrim.service
# /usr/share/doc/util-linux/examples/motd
# /usr/share/doc/util-linux/examples/getopt-parse.tcsh
# /usr/share/doc/util-linux/examples/udev-raw.rules
# /usr/share/doc/util-linux/examples/getopt-parse.bash
# /usr/share/doc/util-linux/examples/filesystems
# /usr/share/doc/util-linux/examples/fstrim.timer
# /usr/share/doc/util-linux/examples/shells
# /usr/share/doc/util-linux/examples/fstab.example2
# /usr/share/doc/util-linux/examples/securetty
# /usr/share/doc/perl/
# /usr/share/doc/perl/README.Debian
# /usr/share/doc/perl/AUTHORS.gz
# /usr/share/doc/perl/Documentation
# /usr/share/doc/perl/copyright
# /usr/share/doc/perl/changelog.Debian.gz
# /usr/share/doc/perl/changelog.gz
# /usr/share/doc/perl/Changes.gz
# /usr/share/doc/libtinfo5/
# /usr/share/doc/libtinfo5/TODO.Debian
# /usr/share/doc/libtinfo5/copyright
# /usr/share/doc/libtinfo5/changelog.Debian.gz
# /usr/share/doc/libss2/
# /usr/share/doc/libss2/copyright
# /usr/share/doc/libss2/changelog.Debian.gz
# /usr/share/doc/libpam-runtime/
# /usr/share/doc/libpam-runtime/NEWS.Debian.gz
# /usr/share/doc/libpam-runtime/copyright
# /usr/share/doc/libpam-runtime/changelog.Debian.gz
# /usr/share/doc/hostname/
# /usr/share/doc/hostname/changelog.gz
# /usr/share/doc/hostname/copyright
# /usr/share/doc/gcc-5-base/
# /usr/share/doc/gcc-5-base/TODO.Debian
# /usr/share/doc/gcc-5-base/README.Debian.amd64.gz
# /usr/share/doc/gcc-5-base/copyright
# /usr/share/doc/gcc-5-base/changelog.Debian.gz
# /usr/share/doc/gcc-5-base/NEWS.gz
# /usr/share/doc/gcc-5-base/README.Bugs
# /usr/share/doc/gcc-5-base/changelog.gz
# /usr/share/doc/gcc-5-base/sanitizer/
# /usr/share/doc/gcc-5-base/sanitizer/changelog.gz
# /usr/share/doc/gcc-5-base/gomp/
# /usr/share/doc/gcc-5-base/gomp/changelog.gz
# /usr/share/doc/gcc-5-base/gcc.css
# /usr/share/doc/gcc-5-base/gcc/
# /usr/share/doc/gcc-5-base/gcc/changelog.gz
# /usr/share/doc/gcc-5-base/C++/
# /usr/share/doc/gcc-5-base/C++/changelog.gz
# /usr/share/doc/gcc-5-base/C++/README.C++
# /usr/share/doc/gcc-5-base/C++/changelog.libstdc++.gz
# /usr/share/doc/gcc-5-base/cilkrts/
# /usr/share/doc/gcc-5-base/cilkrts/changelog.gz
# /usr/share/doc/gcc-5-base/NEWS.html
# /usr/share/doc/gcc-5-base/itm/
# /usr/share/doc/gcc-5-base/itm/changelog.gz
# /usr/share/doc/gcc-5-base/README.ssp
# /usr/share/doc/gcc-5-base/mpx/
# /usr/share/doc/gcc-5-base/mpx/changelog.gz
# /usr/share/doc/gcc-5-base/fortran/
# /usr/share/doc/gcc-5-base/fortran/changelog.gz
# /usr/share/doc/gcc-5-base/quadmath/
# /usr/share/doc/gcc-5-base/quadmath/changelog.gz
# /usr/share/doc/readline-common/
# /usr/share/doc/readline-common/inputrc.arrows
# /usr/share/doc/readline-common/copyright
# /usr/share/doc/readline-common/changelog.Debian.gz
# /usr/share/doc/ncurses-base/
# /usr/share/doc/ncurses-base/copyright
# /usr/share/doc/ncurses-base/changelog.Debian.gz
# /usr/share/doc/libkmod2/
# /usr/share/doc/libkmod2/copyright
# /usr/share/doc/libkmod2/changelog.Debian.gz
# /usr/share/doc/gnupg/
# /usr/share/doc/gnupg/TODO.Debian
# /usr/share/doc/gnupg/FAQ
# /usr/share/doc/gnupg/README.Debian
# /usr/share/doc/gnupg/DETAILS.gz
# /usr/share/doc/gnupg/THANKS.gz
# /usr/share/doc/gnupg/AUTHORS.gz
# /usr/share/doc/gnupg/highlights-1.4.txt.gz
# /usr/share/doc/gnupg/README.gz
# /usr/share/doc/gnupg/TODO
# /usr/share/doc/gnupg/copyright
# /usr/share/doc/gnupg/OpenPGP.gz
# /usr/share/doc/gnupg/changelog.Debian.gz
# /usr/share/doc/gnupg/README.BUGS.Debian.gz
# /usr/share/doc/gnupg/Upgrading_From_PGP.txt
# /usr/share/doc/gnupg/examples/
# /usr/share/doc/gnupg/examples/convert-from-106
# /usr/share/doc/sed/
# /usr/share/doc/sed/NEWS.gz
# /usr/share/doc/sed/BUGS.gz
# /usr/share/doc/sed/THANKS.gz
# /usr/share/doc/sed/sedfaq.txt.gz
# /usr/share/doc/sed/AUTHORS.gz
# /usr/share/doc/sed/README.gz
# /usr/share/doc/sed/copyright
# /usr/share/doc/sed/changelog.Debian.gz
# /usr/share/doc/sed/examples/
# /usr/share/doc/sed/examples/dc.sed
# /usr/share/doc/libsepol1/
# /usr/share/doc/libsepol1/copyright
# /usr/share/doc/libsepol1/changelog.Debian.gz
# /usr/share/doc/base-passwd/
# /usr/share/doc/base-passwd/changelog.gz
# /usr/share/doc/base-passwd/README
# /usr/share/doc/base-passwd/copyright
# /usr/share/doc/base-passwd/users-and-groups.txt.gz
# /usr/share/doc/base-passwd/users-and-groups.html
# /usr/share/doc/libcap2-bin/
# /usr/share/doc/libcap2-bin/README.Debian
# /usr/share/doc/libcap2-bin/copyright
# /usr/share/doc/libcap2-bin/changelog.Debian.gz
# /usr/share/doc/libdevmapper1.02.1/
# /usr/share/doc/libdevmapper1.02.1/copyright
# /usr/share/doc/libdevmapper1.02.1/changelog.Debian.gz
# /usr/share/doc/diffutils/
# /usr/share/doc/diffutils/NEWS.gz
# /usr/share/doc/diffutils/copyright
# /usr/share/doc/diffutils/changelog.Debian.gz
# /usr/share/doc/libsemanage1/
# /usr/share/doc/libsemanage1/copyright
# /usr/share/doc/libsemanage1/changelog.Debian.gz
# /usr/share/doc/libc6/
# /usr/share/doc/libc6/NEWS.gz
# /usr/share/doc/libc6/BUGS
# /usr/share/doc/libc6/NEWS.Debian.gz
# /usr/share/doc/libc6/README.Debian.gz
# /usr/share/doc/libc6/copyright
# /usr/share/doc/libc6/changelog.Debian.gz
# /usr/share/doc/libc6/README.hesiod.gz
# /usr/share/doc/libseccomp2/
# /usr/share/doc/libseccomp2/copyright
# /usr/share/doc/libseccomp2/changelog.Debian.gz
# /usr/share/doc/e2fslibs/
# /usr/share/doc/e2fslibs/copyright
# /usr/share/doc/e2fslibs/changelog.Debian.gz
# /usr/share/doc/libbz2-1.0/
# /usr/share/doc/libbz2-1.0/copyright
# /usr/share/doc/libbz2-1.0/changelog.Debian.gz
# /usr/share/doc/mawk/
# /usr/share/doc/mawk/ACKNOWLEDGMENT
# /usr/share/doc/mawk/README
# /usr/share/doc/mawk/copyright
# /usr/share/doc/mawk/changelog.Debian.gz
# /usr/share/doc/mawk/examples/
# /usr/share/doc/mawk/examples/hcal.gz
# /usr/share/doc/mawk/examples/nocomment.awk
# /usr/share/doc/mawk/examples/decl.awk
# /usr/share/doc/mawk/examples/deps.awk
# /usr/share/doc/mawk/examples/gdecl.awk
# /usr/share/doc/mawk/examples/eatc.awk
# /usr/share/doc/mawk/examples/primes.awk
# /usr/share/doc/mawk/examples/hical
# /usr/share/doc/mawk/examples/qsort.awk
# /usr/share/doc/mawk/examples/ct_length.awk
# /usr/share/doc/procps/
# /usr/share/doc/procps/README.Debian
# /usr/share/doc/procps/README.top.gz
# /usr/share/doc/procps/BUGS
# /usr/share/doc/procps/NEWS.Debian.gz
# /usr/share/doc/procps/FAQ.gz
# /usr/share/doc/procps/copyright
# /usr/share/doc/procps/changelog.Debian.gz
# /usr/share/doc/procps/TODO.gz
# /usr/share/doc/procps/examples/
# /usr/share/doc/procps/examples/sysctl.conf
# /usr/share/doc/liblz4-1/
# /usr/share/doc/liblz4-1/copyright
# /usr/share/doc/liblz4-1/changelog.Debian.gz
# /usr/share/doc/grep/
# /usr/share/doc/grep/NEWS.gz
# /usr/share/doc/grep/THANKS.gz
# /usr/share/doc/grep/README
# /usr/share/doc/grep/AUTHORS
# /usr/share/doc/grep/copyright
# /usr/share/doc/grep/changelog.Debian.gz
# /usr/share/doc/grep/TODO.gz
# /usr/share/doc/multiarch-support/
# /usr/share/doc/multiarch-support/copyright
# /usr/share/doc/multiarch-support/changelog.Debian.gz
# /usr/share/doc/coreutils/
# /usr/share/doc/coreutils/NEWS.gz
# /usr/share/doc/coreutils/README.Debian
# /usr/share/doc/coreutils/NEWS.Debian.gz
# /usr/share/doc/coreutils/THANKS.gz
# /usr/share/doc/coreutils/README.gz
# /usr/share/doc/coreutils/AUTHORS
# /usr/share/doc/coreutils/copyright
# /usr/share/doc/coreutils/changelog.Debian.gz
# /usr/share/doc/coreutils/TODO.gz
# /usr/share/doc/libdb5.3/
# /usr/share/doc/libdb5.3/copyright
# /usr/share/doc/libdb5.3/changelog.Debian.gz
# /usr/share/doc/libdb5.3/build_signature_amd64.txt
# /usr/share/doc/ubuntu-keyring/
# /usr/share/doc/ubuntu-keyring/changelog.gz
# /usr/share/doc/ubuntu-keyring/README.gz
# /usr/share/doc/ubuntu-keyring/copyright
# /usr/share/doc/base-files/
# /usr/share/doc/base-files/changelog.gz
# /usr/share/doc/base-files/FAQ
# /usr/share/doc/base-files/README
# /usr/share/doc/base-files/README.FHS
# /usr/share/doc/base-files/copyright
# /usr/share/doc/ncurses-bin/
# /usr/share/doc/ncurses-bin/FAQ
# /usr/share/doc/ncurses-bin/copyright
# /usr/share/doc/ncurses-bin/changelog.Debian.gz
# /usr/share/doc/postgresql-client-common/
# /usr/share/doc/postgresql-client-common/changelog.gz
# /usr/share/doc/postgresql-client-common/copyright
# /usr/share/doc/libprotobuf-c1/
# /usr/share/doc/libprotobuf-c1/copyright
# /usr/share/doc/libprotobuf-c1/changelog.Debian.gz
# /usr/share/doc/libkadm5clnt-mit9/
# /usr/share/doc/libkadm5clnt-mit9/NEWS.Debian.gz
# /usr/share/doc/libkadm5clnt-mit9/copyright
# /usr/share/doc/libkadm5clnt-mit9/changelog.Debian.gz
# /usr/share/doc/libprotobuf-c-dev/
# /usr/share/doc/libprotobuf-c-dev/copyright
# /usr/share/doc/libprotobuf-c-dev/changelog.Debian.gz
# /usr/share/doc/sysstat/
# /usr/share/doc/sysstat/CREDITS.gz
# /usr/share/doc/sysstat/xml/
# /usr/share/doc/sysstat/xml/sysstat-3.1.dtd.gz
# /usr/share/doc/sysstat/xml/sysstat.xsd.gz
# /usr/share/doc/sysstat/README.Debian
# /usr/share/doc/sysstat/NEWS.Debian.gz
# /usr/share/doc/sysstat/README.gz
# /usr/share/doc/sysstat/FAQ.gz
# /usr/share/doc/sysstat/copyright
# /usr/share/doc/sysstat/changelog.Debian.gz
# /usr/share/doc/sysstat/examples/
# /usr/share/doc/sysstat/examples/sargraph.gz
# /usr/share/doc/sysstat/examples/irqstat.gz
# /usr/share/doc/sysstat/examples/irqtop.gz
# /usr/share/doc/sysstat/examples/README.irqstat
# /usr/share/doc/sysstat/examples/crontab
# /usr/share/doc/sysstat/examples/sargraph2.gz
# /usr/share/doc/postgresql-9.5/
# /usr/share/doc/postgresql-9.5/NEWS.Debian.gz
# /usr/share/doc/postgresql-9.5/README.Debian.gz
# /usr/share/doc/postgresql-9.5/copyright
# /usr/share/doc/postgresql-9.5/changelog.Debian.gz
# /usr/share/doc/tzdata/
# /usr/share/doc/tzdata/README.Debian
# /usr/share/doc/tzdata/copyright
# /usr/share/doc/tzdata/changelog.Debian.gz
# /usr/share/doc/libpq5/
# /usr/share/doc/libpq5/copyright
# /usr/share/doc/libpq5/changelog.Debian.gz
# /usr/share/doc/postgresql-server-dev-all/
# /usr/share/doc/postgresql-server-dev-all/changelog.gz
# /usr/share/doc/postgresql-server-dev-all/copyright
# /usr/share/doc/logrotate/
# /usr/share/doc/logrotate/README.Debian
# /usr/share/doc/logrotate/NEWS.Debian.gz
# /usr/share/doc/logrotate/copyright
# /usr/share/doc/logrotate/changelog.Debian.gz
# /usr/share/doc/ssl-cert/
# /usr/share/doc/ssl-cert/changelog.gz
# /usr/share/doc/ssl-cert/README
# /usr/share/doc/ssl-cert/copyright
# /usr/share/doc/postgresql/
# /usr/share/doc/postgresql/changelog.gz
# /usr/share/doc/postgresql/copyright
# /usr/share/doc/postgresql-contrib-9.5/
# /usr/share/doc/postgresql-contrib-9.5/autoinc.example
# /usr/share/doc/postgresql-contrib-9.5/moddatetime.example
# /usr/share/doc/postgresql-contrib-9.5/refint.example
# /usr/share/doc/postgresql-contrib-9.5/copyright
# /usr/share/doc/postgresql-contrib-9.5/changelog.Debian.gz
# /usr/share/doc/postgresql-contrib-9.5/timetravel.example
# /usr/share/doc/postgresql-contrib-9.5/insert_username.example
# /usr/share/doc/protobuf-c-compiler/
# /usr/share/doc/protobuf-c-compiler/copyright
# /usr/share/doc/protobuf-c-compiler/changelog.Debian.gz
# /usr/share/doc/krb5-multidev/
# /usr/share/doc/krb5-multidev/NEWS.Debian.gz
# /usr/share/doc/krb5-multidev/copyright
# /usr/share/doc/krb5-multidev/changelog.Debian.gz
# /usr/share/doc/dctrl-tools/
# /usr/share/doc/dctrl-tools/NEWS.Debian.gz
# /usr/share/doc/dctrl-tools/README
# /usr/share/doc/dctrl-tools/TODO
# /usr/share/doc/dctrl-tools/copyright
# /usr/share/doc/dctrl-tools/changelog.Debian.gz
# /usr/share/doc/postgresql-common/
# /usr/share/doc/postgresql-common/dependencies.png
# /usr/share/doc/postgresql-common/changelog.gz
# /usr/share/doc/postgresql-common/NEWS.Debian.gz
# /usr/share/doc/postgresql-common/README.Debian.gz
# /usr/share/doc/postgresql-common/architecture.html
# /usr/share/doc/postgresql-common/README.Devel
# /usr/share/doc/postgresql-common/README.systemd
# /usr/share/doc/postgresql-common/copyright
# /usr/share/doc/postgresql-client-9.5/
# /usr/share/doc/postgresql-client-9.5/copyright
# /usr/share/doc/postgresql-client-9.5/changelog.Debian.gz
# /usr/share/doc/libssl-doc/
# /usr/share/doc/libssl-doc/demos/
# /usr/share/doc/libssl-doc/demos/easy_tls/
# /usr/share/doc/libssl-doc/demos/easy_tls/easy-tls.c.gz
# /usr/share/doc/libssl-doc/demos/easy_tls/cacerts.pem
# /usr/share/doc/libssl-doc/demos/easy_tls/test.h
# /usr/share/doc/libssl-doc/demos/easy_tls/Makefile
# /usr/share/doc/libssl-doc/demos/easy_tls/cert.pem
# /usr/share/doc/libssl-doc/demos/easy_tls/easy-tls.h
# /usr/share/doc/libssl-doc/demos/easy_tls/test.c.gz
# /usr/share/doc/libssl-doc/demos/easy_tls/README
# /usr/share/doc/libssl-doc/demos/cms/
# /usr/share/doc/libssl-doc/demos/cms/cakey.pem
# /usr/share/doc/libssl-doc/demos/cms/cms_ddec.c
# /usr/share/doc/libssl-doc/demos/cms/comp.txt
# /usr/share/doc/libssl-doc/demos/cms/encr.txt
# /usr/share/doc/libssl-doc/demos/cms/cms_uncomp.c
# /usr/share/doc/libssl-doc/demos/cms/cacert.pem
# /usr/share/doc/libssl-doc/demos/cms/cms_sign.c
# /usr/share/doc/libssl-doc/demos/cms/cms_sign2.c
# /usr/share/doc/libssl-doc/demos/cms/cms_denc.c
# /usr/share/doc/libssl-doc/demos/cms/cms_enc.c
# /usr/share/doc/libssl-doc/demos/cms/sign.txt
# /usr/share/doc/libssl-doc/demos/cms/cms_comp.c
# /usr/share/doc/libssl-doc/demos/cms/cms_ver.c
# /usr/share/doc/libssl-doc/demos/cms/cms_dec.c
# /usr/share/doc/libssl-doc/demos/cms/signer2.pem

# %% [markdown]
# ---
# ### *Here's what you need to know to complete the project:*
#
# Some template code has already been provided for you, but you'll need to implement additional code steps to successfully complete this project. Any code that is required to pass this project is marked with **'(IMPLEMENTATION)'** in the header. There are also a couple of questions about your thoughts as you work through this project, which are marked with **'(QUESTION)'** in the header. Make sure to answer all questions and to check your work against the [project rubric](https://review.udacity.com/#!/rubrics/1213/view) to make sure you complete the necessary classification steps!
#
# Your project submission will be evaluated based on the code implementations you provide, and on two main classification criteria.
# Your complete traffic light classifier should have:
# 1. **Greater than 90% accuracy**
# 2. ***Never* classify red lights as green**

# %% [markdown]
# # 1. Loading and Visualizing the Traffic Light Dataset
#
# This traffic light dataset consists of 1484 number of color images in 3 categories - red, yellow, and green. As with most human-sourced data, the data is not evenly distributed among the types. There are:
# * 904 red traffic light images
# * 536 green traffic light images
# * 44 yellow traffic light images
#
# *Note: All images come from this [MIT self-driving car course](https://selfdrivingcars.mit.edu/) and are licensed under a [Creative Commons Attribution-ShareAlike 4.0 International License](https://creativecommons.org/licenses/by-sa/4.0/).*

# %% [markdown]
# ### Import resources
#
# Before you get started on the project code, import the libraries and resources that you'll need.

# %%
import cv2 # computer vision library
import helpers # helper functions

import random
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # for loading in images

# %matplotlib inline

# %% [markdown]
# ## Training and Testing Data
#
# All 1484 of the traffic light images are separated into training and testing datasets.
#
# * 80% of these images are training images, for you to use as you create a classifier.
# * 20% are test images, which will be used to test the accuracy of your classifier.
# * All images are pictures of 3-light traffic lights with one light illuminated.
#
# ## Define the image directories
#
# First, we set some variables to keep track of some where our images are stored:
#
#     IMAGE_DIR_TRAINING: the directory where our training image data is stored
#     IMAGE_DIR_TEST: the directory where our test image data is stored

# %%
# Image data directories
IMAGE_DIR_TRAINING = "traffic_light_images/training/"
IMAGE_DIR_TEST = "traffic_light_images/test/"

# %% [markdown]
# ## Load the datasets
#
# These first few lines of code will load the training traffic light images and store all of them in a variable, `IMAGE_LIST`. This list contains the images and their associated label ("red", "yellow", "green").
#
# You are encouraged to take a look at the `load_dataset` function in the helpers.py file. This will give you a good idea about how lots of image files can be read in from a directory using the [glob library](https://pymotw.com/2/glob/). The `load_dataset` function takes in the name of an image directory and returns a list of images and their associated labels.
#
# For example, the first image-label pair in `IMAGE_LIST` can be accessed by index:
# ``` IMAGE_LIST[0][:]```.

# %%
# Using the load_dataset function in helpers.py
# Load training data
IMAGE_LIST = helpers.load_dataset(IMAGE_DIR_TRAINING)

IMAGE_LIST[0][:]
# Out:
# (array([[[225, 225, 225],
#          [218, 214, 215],
#          [216, 207, 210],
#          ...,
#          [224, 222, 225],
#          [202, 200, 203],
#          [148, 146, 149]],
#
#         [[226, 224, 225],
#          [218, 214, 215],
#          [217, 208, 211],
#          ...,
#          [230, 228, 231],
#          [202, 200, 203],
#          [152, 150, 153]],
#
#         [[226, 222, 223],
#          [218, 212, 214],
#          [214, 210, 211],
#          ...,
#          [233, 233, 235],
#          [200, 198, 201],
#          [154, 152, 155]],
#
#         ...,
#         [[240, 235, 239],
#          [243, 238, 242],
#          [244, 239, 243],
#          ...,
#          [117, 122, 118],
#          [ 92,  97,  93],
#          [ 70,  75,  71]],
#
#         [[239, 233, 237],
#          [241, 236, 240],
#          [243, 238, 242],
#          ...,
#          [119, 121, 118],
#          [109, 111, 108],
#          [ 97,  99,  96]],
#
#         [[237, 231, 235],
#          [240, 235, 239],
#          [242, 237, 241],
#          ...,
#          [125, 127, 124],
#          [123, 125, 122],
#          [115, 117, 114]]], dtype=uint8), 'red')

# %% [markdown]
# ## Visualize the Data
#
# The first steps in analyzing any dataset are to 1. load the data and 2. look at the data. Seeing what it looks like will give you an idea of what to look for in the images, what kind of noise or inconsistencies you have to deal with, and so on. This will help you understand the image dataset, and **understanding a dataset is part of making predictions about the data**.

# %% [markdown]
# ---
# ### Visualize the input images
#
# Visualize and explore the image data! Write code to display an image in `IMAGE_LIST`:
# * Display the image
# * Print out the shape of the image
# * Print out its corresponding label
#
# See if you can display at least one of each type of traffic light image – red, green, and yellow — and look at their similarities and differences.

# %%
## TODO: Write code to display an image in IMAGE_LIST (try finding a yellow traffic light!)
## TODO: Print out 1. The shape of the image and 2. The image's label

# The first image in IMAGE_LIST is displayed below (without information about shape or label)
selected_image = IMAGE_LIST[0][0]
plt.imshow(selected_image)
print(IMAGE_LIST[0][1])
print(IMAGE_LIST[0][0].shape)
# Out:
# red
# (82, 37, 3)

# %% [markdown]
# # 2. Pre-process the Data
#
# After loading in each image, you have to standardize the input and output!
#
# ### Input
#
# This means that every input image should be in the same format, of the same size, and so on. We'll be creating features by performing the same analysis on every picture, and for a classification task like this, it's important that **similar images create similar features**!
#
# ### Output
#
# We also need the output to be a label that is easy to read and easy to compare with other labels. It is good practice to convert categorical data like "red" and "green" to numerical data.
#
# A very common classification output is a 1D list that is the length of the number of classes - three in the case of red, yellow, and green lights - with the values 0 or 1 indicating which class a certain image is. For example, since we have three classes (red, yellow, and green), we can make a list with the order: [red value, yellow value, green value]. In general, order does not matter, we choose the order [red value, yellow value, green value] in this case to reflect the position of each light in descending vertical order.
#
# A red light should have the  label: [1, 0, 0]. Yellow should be: [0, 1, 0]. Green should be: [0, 0, 1]. These labels are called **one-hot encoded labels**.
#
# *(Note: one-hot encoding will be especially important when you work with [machine learning algorithms](https://machinelearningmastery.com/how-to-one-hot-encode-sequence-data-in-python/)).*
#
# <img src="images/processing_steps.png" width="80%" height="80%">

# %% [markdown]
# ---
# <a id='task2'></a>
# ### (IMPLEMENTATION): Standardize the input images
#
# * Resize each image to the desired input size: 32x32px.
# * (Optional) You may choose to crop, shift, or rotate the images in this step as well.
#
# It's very common to have square input sizes that can be rotated (and remain the same size), and analyzed in smaller, square patches. It's also important to make all your images the same size so that they can be sent through the same pipeline of classification steps!

# %%
# This function should take in an RGB image and return a new, standardized version
def standardize_input(image):
    ## TODO: Resize image and pre-process so that all "standard" images are the same size  
    standard_im = np.copy(image)
    return cv2.resize(standard_im, (32, 32))

# %% [markdown]
# ## Standardize the output
#
# With each loaded image, we also specify the expected output. For this, we use **one-hot encoding**.
#
# * One-hot encode the labels. To do this, create an array of zeros representing each class of traffic light (red, yellow, green), and set the index of the expected class number to 1.
#
# Since we have three classes (red, yellow, and green), we have imposed an order of: [red value, yellow value, green value]. To one-hot encode, say, a yellow light, we would first initialize an array to [0, 0, 0] and change the middle value (the yellow value) to 1: [0, 1, 0].

# %% [markdown]
# ---
# <a id='task3'></a>
# ### (IMPLEMENTATION): Implement one-hot encoding

# %%
## TODO: One hot encode an image label
## Given a label - "red", "green", or "yellow" - return a one-hot encoded label

# Examples: 
# one_hot_encode("red") should return: [1, 0, 0]
# one_hot_encode("yellow") should return: [0, 1, 0]
# one_hot_encode("green") should return: [0, 0, 1]

def one_hot_encode(label):
    ## TODO: Create a one-hot encoded label that works for all classes of traffic lights 
    one_hot_encoded = [0, 0, 0] 
    if (label == "red"):
        one_hot_encoded = [1, 0, 0] 
    elif (label == "yellow"):
        one_hot_encoded = [0, 1, 0] 
    elif (label == "green"):
        one_hot_encoded = [0, 0, 1]  
    else:
        raise ValueError("Label not recognized")
    return one_hot_encoded

# %% [markdown]
# ### Testing as you Code
#
# After programming a function like this, it's a good idea to test it, and see if it produces the expected output. **In general, it's good practice to test code in small, functional pieces, after you write it**. This way, you can make sure that your code is correct as you continue to build a classifier, and you can identify any errors early on so that they don't compound.
#
# All test code can be found in the file `test_functions.py`. You are encouraged to look through that code and add your own testing code if you find it useful!
#
# One test function you'll find is: `test_one_hot(self, one_hot_function)` which takes in one argument, a one_hot_encode function, and tests its functionality. If your one_hot_label code does not work as expected, this test will print ot an error message that will tell you a bit about why your code failed. Once your code works, this should print out TEST PASSED.

# %%
# Importing the tests
import test_functions
tests = test_functions.Tests()

# Test for one_hot_encode function
tests.test_one_hot(one_hot_encode)
# Out:
# **<span style="color: green;">TEST PASSED</span>**

# %% [markdown]
# ## Construct a `STANDARDIZED_LIST` of input images and output labels.
#
# This function takes in a list of image-label pairs and outputs a **standardized** list of resized images and one-hot encoded labels.
#
# This uses the functions you defined above to standardize the input and output, so those functions must be complete for this standardization to work!

# %%
def standardize(image_list):
    
    # Empty image data array
    standard_list = []

    # Iterate through all the image-label pairs
    for item in image_list:
        image = item[0]
        label = item[1]

        # Standardize the image
        standardized_im = standardize_input(image)

        # One-hot encode the label
        one_hot_label = one_hot_encode(label)    

        # Append the image, and it's one hot encoded label to the full, processed list of image data 
        standard_list.append((standardized_im, one_hot_label))
        
    return standard_list

# Standardize all training images
STANDARDIZED_LIST = standardize(IMAGE_LIST)

# %% [markdown]
# ## Visualize the standardized data
#
# Display a standardized image from STANDARDIZED_LIST and compare it with a non-standardized image from IMAGE_LIST. Note that their sizes and appearance are different!

# %%
## TODO: Display a standardized image and its label
image_num = 0
selected_image_standardized = STANDARDIZED_LIST[image_num][0]
selected_label_standardized = STANDARDIZED_LIST[image_num][1]

selected_image = IMAGE_LIST[image_num][0]
selected_label = IMAGE_LIST[image_num][1]

f, ax = plt.subplots(1,2)
ax[0].imshow(selected_image)
ax[0].set_title(selected_label)
ax[1].imshow(selected_image_standardized)
ax[1].set_title(selected_label_standardized)

print("Shape original image: " + str(selected_image.shape))
print("Shape standardized image: " + str(selected_image_standardized.shape))
# Out:
# Shape original image: (82, 37, 3)
# Shape standardized image: (32, 32, 3)

# %% [markdown]
# # 3. Feature Extraction
#
# You'll be using what you now about color spaces, shape analysis, and feature construction to create features that help distinguish and classify the three types of traffic light images.
#
# You'll be tasked with creating **one feature** at a minimum (with the option to create more). The required feature is **a brightness feature using HSV color space**:
#
# 1. A brightness feature.
#     - Using HSV color space, create a feature that helps you identify the 3 different classes of traffic light.
#     - You'll be asked some questions about what methods you tried to locate this traffic light, so, as you progress through this notebook, always be thinking about your approach: what works and what doesn't?
#
# 2. (Optional): Create more features!
#
# Any more features that you create are up to you and should improve the accuracy of your traffic light classification algorithm! One thing to note is that, to pass this project you must **never classify a red light as a green light** because this creates a serious safety risk for a self-driving car. To avoid this misclassification, you might consider adding another feature that specifically distinguishes between red and green lights.
#
# These features will be combined near the end of his notebook to form a complete classification algorithm.

# %% [markdown]
# ## Creating a brightness feature
#
# There are a number of ways to create a brightness feature that will help you characterize images of traffic lights, and it will be up to you to decide on the best procedure to complete this step. You should visualize and test your code as you go.
#
# Pictured below is a sample pipeline for creating a brightness feature (from left to right: standardized image, HSV color-masked image, cropped image, brightness feature):
#
# <img src="images/feature_ext_steps.png" width="70%" height="70%">

# %% [markdown]
# ## RGB to HSV conversion
#
# Below, a test image is converted from RGB to HSV colorspace and each component is displayed in an image.

# %%
# Convert and image to HSV colorspace
# Visualize the individual color channels

image_num = 40
test_im = STANDARDIZED_LIST[image_num][0]
test_label = STANDARDIZED_LIST[image_num][1]

# Convert to HSV
hsv = cv2.cvtColor(test_im, cv2.COLOR_RGB2HSV)

# Print image label
print('Label [red, yellow, green]: ' + str(test_label))

# HSV channels
h = hsv[:,:,0]
s = hsv[:,:,1]
v = hsv[:,:,2]

# Plot the original image and the three channels
f, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(20,10))
ax1.set_title('Standardized image')
ax1.imshow(test_im)
ax2.set_title('H channel')
ax2.imshow(h, cmap='gray')
ax3.set_title('S channel')
ax3.imshow(s, cmap='gray')
ax4.set_title('V channel')
ax4.imshow(v, cmap='gray')
# Out:
# Label [red, yellow, green]: [1, 0, 0]

# %% [markdown]
# ---
# <a id='task7'></a>
# ### (IMPLEMENTATION): Create a brightness feature that uses HSV color space
#
# Write a function that takes in an RGB image and returns a 1D feature vector and/or single value that will help classify an image of a traffic light. The only requirement is that this function should apply an HSV colorspace transformation, the rest is up to you.
#
# From this feature, you should be able to estimate an image's label and classify it as either a red, green, or yellow traffic light. You may also define helper functions if they simplify your code.

# %%
## TODO: Create a brightness feature that takes in an RGB image and outputs a feature vector and/or value
## This feature should use HSV colorspace values
def create_feature(rgb_image):
    
    hsv = cv2.cvtColor(rgb_image, cv2.COLOR_RGB2HSV)
    
    s_average = int(np.sum(hsv[:,:,1])/(32*32))
    v_average = int(np.sum(hsv[:,:,2])/(32*32))
    
    lower_red = np.array([142, s_average, v_average])
    upper_red = np.array([180,255,255])
    red_mask = cv2.inRange(hsv, lower_red, upper_red)
    
    red = np.copy(rgb_image)
    red[red_mask==0] = [0,0,0]
    #plt.imshow(red)
    red_sum = np.sum(red[4:12, 13:22])
    
    lower_yellow = np.array([9,s_average, v_average])
    upper_yellow = np.array([51,255,255])
    yellow_mask = cv2.inRange(hsv, lower_yellow, upper_yellow)
    
    yellow = np.copy(rgb_image)
    yellow[yellow_mask==0] = [0,0,0]
    yellow_sum = np.sum(yellow[13:21, 12:22])
    
    lower_green = np.array([62, s_average, v_average])
    upper_green = np.array([95,255,255])
    green_mask = cv2.inRange(hsv, lower_green, upper_green)
    
    green = np.copy(rgb_image)
    green[green_mask==0] = [0,0,0]
    green_sum = np.sum(green[22:32, 12:23])   
    
    return red_sum, yellow_sum, green_sum

# %%
image_num = 40
selected_image = STANDARDIZED_LIST[image_num][0]
red, yellow, green = create_feature(selected_image)
red, yellow, green
# Out:
# (7975, 0, 0)

# %% [markdown]
# ## (Optional) Create more features to help accurately label the traffic light images

# %%
# (Optional) Add more image analysis and create more features

# %% [markdown]
# ## (QUESTION 1): How do the features you made help you distinguish between the 3 classes of traffic light images?

# %% [markdown]
# **Answer:**
# First I decided to isolate areas of the image with saturation and value (in HSV space) above average (basically areas where the traffic light is on) and then I used a mask to help distinguish each color. (The Hue threshold was chosen from here http://colorizer.org/). Lastly, I divided the image in three vertical regions and calculated the intensity of pixels in a specific region.

# %% [markdown]
# # 4. Classification and Visualizing Error
#
# Using all of your features, write a function that takes in an RGB image and, using your extracted features, outputs whether a light is red, green or yellow as a one-hot encoded label. This classification function should be able to classify any image of a traffic light!
#
# You are encouraged to write any helper functions or visualization code that you may need, but for testing the accuracy, make sure that this `estimate_label` function returns a one-hot encoded label.

# %% [markdown]
# ---
# <a id='task8'></a>
# ### (IMPLEMENTATION): Build a complete classifier

# %%
# This function should take in RGB image input
# Analyze that image using your feature creation code and output a one-hot encoded label
def estimate_label(rgb_image):
    
    ## TODO: Extract feature(s) from the RGB image and use those features to
    ## classify the image and output a one-hot encoded label
    predicted_label = [0, 1, 0]   
    red, yellow, green = create_feature(rgb_image)  
    if (red > yellow and red > green):
        predicted_label = [1, 0, 0]
        flag = 1
    if (yellow > red and yellow > green):
        predicted_label = [0, 1, 0]
        flag = 1
    if (green > red and green > yellow):
        predicted_label = [0, 0, 1]  
        flag = 1

    return predicted_label

# %%
image_num = 0
selected_image = STANDARDIZED_LIST[image_num][0]
predicted_label = estimate_label(selected_image)
print("Predicted Label:", predicted_label) 
print("True Label:", STANDARDIZED_LIST[image_num][1]) 
plt.imshow(selected_image)
# Out:
# Predicted Label: [1, 0, 0]
# True Label: [1, 0, 0]

# %% [markdown]
# ## Testing the classifier
#
# Here is where we test your classification algorithm using our test set of data that we set aside at the beginning of the notebook! This project will be complete once you've pogrammed a "good" classifier.
#
# A "good" classifier in this case should meet the following criteria (and once it does, feel free to submit your project):
# 1. Get above 90% classification accuracy.
# 2. Never classify a red light as a green light.
#
# ### Test dataset
#
# Below, we load in the test dataset, standardize it using the `standardize` function you defined above, and then **shuffle** it; this ensures that order will not play a role in testing accuracy.

# %%
# Using the load_dataset function in helpers.py
# Load test data
TEST_IMAGE_LIST = helpers.load_dataset(IMAGE_DIR_TEST)

# Standardize the test data
STANDARDIZED_TEST_LIST = standardize(TEST_IMAGE_LIST)

# Shuffle the standardized test data
random.shuffle(STANDARDIZED_TEST_LIST)

# %% [markdown]
# ## Determine the Accuracy
#
# Compare the output of your classification algorithm (a.k.a. your "model") with the true labels and determine the accuracy.
#
# This code stores all the misclassified images, their predicted labels, and their true labels, in a list called `MISCLASSIFIED`. This code is used for testing and *should not be changed*.

# %%
# Constructs a list of misclassified images given a list of test images and their labels
# This will throw an AssertionError if labels are not standardized (one-hot encoded)

def get_misclassified_images(test_images):
    # Track misclassified images by placing them into a list
    misclassified_images_labels = []

    # Iterate through all the test images
    # Classify each image and compare to the true label
    for image in test_images:

        # Get true data
        im = image[0]
        true_label = image[1]
        assert(len(true_label) == 3), "The true_label is not the expected length (3)."

        # Get predicted label from your classifier
        predicted_label = estimate_label(im)
        assert(len(predicted_label) == 3), "The predicted_label is not the expected length (3)."

        # Compare true and predicted labels 
        if(predicted_label != true_label):
            # If these labels are not equal, the image has been misclassified
            misclassified_images_labels.append((im, predicted_label, true_label))
            
    # Return the list of misclassified [image, predicted_label, true_label] values
    return misclassified_images_labels


# Find all misclassified images in a given test set
MISCLASSIFIED = get_misclassified_images(STANDARDIZED_TEST_LIST)

# Accuracy calculations
total = len(STANDARDIZED_TEST_LIST)
num_correct = total - len(MISCLASSIFIED)
accuracy = num_correct/total

print('Accuracy: ' + str(accuracy))
print("Number of misclassified images = " + str(len(MISCLASSIFIED)) +' out of '+ str(total))
# Out:
# Accuracy: 0.9730639730639731
# Number of misclassified images = 8 out of 297

# %% [markdown]
# ---
# <a id='task9'></a>
# ### Visualize the misclassified images
#
# Visualize some of the images you classified wrong (in the `MISCLASSIFIED` list) and note any qualities that make them difficult to classify. This will help you identify any weaknesses in your classification algorithm.

# %%
# Visualize misclassified example(s)
## TODO: Display an image in the `MISCLASSIFIED` list 
## TODO: Print out its predicted label - to see what the image *was* incorrectly classified as
image_num = 4
selected_image = MISCLASSIFIED[image_num][0]
predicted_label = estimate_label(selected_image)
print("Predicted Label", predicted_label) 
print("True Label:", MISCLASSIFIED[image_num][2]) 
plt.imshow(selected_image)
# Out:
# Predicted Label [0, 1, 0]
# True Label: [0, 0, 1]

# %% [markdown]
# ---
# <a id='question2'></a>
# ## (Question 2): After visualizing these misclassifications, what weaknesses do you think your classification algorithm has? Please note at least two.

# %% [markdown]
# **Answer:** Write your answer in this cell.
#
# The algorithm struggles in classifying: 1) images that don't have a distinguishable value of saturation and value above the average and 2) images with uniform color tone.

# %% [markdown]
# ## Test if you classify any red lights as green
#
# **To pass this project, you must not classify any red lights as green!** Classifying red lights as green would cause a car to drive through a red traffic light, so this red-as-green error is very dangerous in the real world.
#
# The code below lets you test to see if you've misclassified any red lights as green in the test set. **This test assumes that `MISCLASSIFIED` is a list of tuples with the order: [misclassified_image, predicted_label, true_label].**
#
# Note: this is not an all encompassing test, but its a good indicator that, if you pass, you are on the right track! This iterates through your list of misclassified examples and checks to see if any red traffic lights have been mistakenly labelled [0, 1, 0] (green).

# %%
# Importing the tests
import test_functions
tests = test_functions.Tests()

if(len(MISCLASSIFIED) > 0):
    # Test code for one_hot_encode function
    tests.test_red_as_green(MISCLASSIFIED)
else:
    print("MISCLASSIFIED may not have been populated with images.")
# Out:
# **<span style="color: green;">TEST PASSED</span>**

# %% [markdown]
# # 5. Improve your algorithm!
#
# **Submit your project after you have completed all implementations, answered all questions, AND when you've met the two criteria:**
# 1. Greater than 90% accuracy classification
# 2. No red lights classified as green
#
# If you did not meet these requirements (which is common on the first attempt!), revisit your algorithm and tweak it to improve light recognition -- this could mean changing the brightness feature, performing some background subtraction, or adding another feature!
#
# ---

# %% [markdown]
# ### Going Further (Optional Challenges)
#
# If you found this challenge easy, I suggest you go above and beyond! Here are a couple **optional** (meaning you do not need to implement these to submit and pass the project) suggestions:
# * (Optional) Aim for >95% classification accuracy.
# * (Optional) Some lights are in the shape of arrows; further classify the lights as round or arrow-shaped.
# * (Optional) Add another feature and aim for as close to 100% accuracy as you can get!
